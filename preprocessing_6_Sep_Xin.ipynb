# %% [markdown]
# ### Step 1: Reading and Understanding the Data

# %%
# Supress Warnings

import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv
from sklearn.impute import SimpleImputer

# %%
lead = pd.read_csv('research_joint_data.csv', encoding = 'latin', error_bad_lines=False)
lead.head()
# Out:
#                    Id    StageName               Status_Reason__c  \
# 0  0062e000002Hc2PAAS  Closed Lost  Customer No Longer Interested
# 1  0062e000002HFaaAAG   Post Award                            NaN
# 2  0062e000002HFabAAG   Post Award                            NaN
# 3  0062e000002HFacAAG       Closed                            NaN
# 4  0062e000002HFadAAG       Closed                            NaN
#
#                       RecordType.Name RICE_Supported__c  \
# 0  Custom Education (MSPACE Included)          RIC-BD&I
# 1                        Parent Grant          RIC-RE&D
# 2                        Parent Grant          RIC-RE&D
# 3                        Parent Grant               NaN
# 4                        Parent Grant               NaN
#
#                 CreatedDate CloseDate Actual_Close_Date__c  \
# 0  2019-11-07T00:59:46.000Z   31/8/20              30/4/20
# 1  2018-09-19T04:32:55.000Z  31/12/49                  NaN
# 2  2018-09-19T04:32:19.000Z   22/6/20              22/6/20
# 3  2016-07-06T05:03:00.000Z  31/12/49                  NaN
# 4  2016-07-21T23:56:54.000Z  31/12/49                  NaN
#
#             AccountId     Lead_Faculty__c      Lead_School__c  \
# 0  0012e000003AqeVAAS  0012e000002ZGfbAAG  0012e000002Zt0mAAC
# 1  0012e000003A6ElAAK                 NaN                 NaN
# 2  0012e000003A6ElAAK                 NaN                 NaN
# 3  0012e000003A6osAAC                 NaN                 NaN
# 4  0012e000003A79XAAS                 NaN                 NaN
#
#   Parent_Opportunity__c      RecordType.Name.1               Industry  \
# 0                   NaN  Business Organization                 Health
# 1                   NaN  Business Organization  Public Administration
# 2                   NaN  Business Organization  Public Administration
# 3                   NaN  Business Organization  Public Administration
# 4                   NaN  Business Organization  Public Administration
#
#           Industry_Sub_Type__c                       Business_Type__c  \
# 0  Health Care & Healthy Aging  Multinational / Other Large Corporate
# 1                          NaN         Government: Australia: Federal
# 2                          NaN         Government: Australia: Federal
# 3                          NaN         Government: Australia: Federal
# 4                          NaN         Government: Australia: Federal
#
#   Is_External__c            ParentId
# 0       External                 NaN
# 1       External  0012e000003A6osAAC
# 2       External  0012e000003A6osAAC
# 3       External  0012e000003A6FfAAK
# 4       External                 NaN

# %%
# inspect lead dataframe

print("*********************************  Info *******************************************") 
print(lead.info())
print("*********************************  Shape ******************************************") 
print(lead.shape)
print("**************************** Columns having null values *****************************")
print(lead.isnull().any())
print("**************************** Describe *****************************")
lead.describe()
# Out:
# *********************************  Info *******************************************
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7597 entries, 0 to 7596
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     7597 non-null   object
#  1   StageName              7597 non-null   object
#  2   Status_Reason__c       7288 non-null   object
#  3   RecordType.Name        7597 non-null   object
#  4   RICE_Supported__c      7569 non-null   object
#  5   CreatedDate            7597 non-null   object
#  6   CloseDate              7597 non-null   object
#  7   Actual_Close_Date__c   6293 non-null   object
#  8   AccountId              6840 non-null   object
#  9   Lead_Faculty__c        6325 non-null   object
#  10  Lead_School__c         4272 non-null   object
#  11  Parent_Opportunity__c  982 non-null    object
#  12  RecordType.Name.1      6840 non-null   object
#  13  Industry               6839 non-null   object
#  14  Industry_Sub_Type__c   4199 non-null   object
#  15  Business_Type__c       6795 non-null   object
#  16  Is_External__c         6840 non-null   object
#  17  ParentId               1140 non-null   object
# dtypes: object(18)
# memory usage: 1.0+ MB
# None
# *********************************  Shape ******************************************
# (7597, 18)
# **************************** Columns having null values *****************************
# Id                       False
# StageName                False
# Status_Reason__c          True
# RecordType.Name          False
# RICE_Supported__c         True
# CreatedDate              False
# CloseDate                False
# Actual_Close_Date__c      True
# AccountId                 True
# Lead_Faculty__c           True
# Lead_School__c            True
# Parent_Opportunity__c     True
# RecordType.Name.1         True
# Industry                  True
# Industry_Sub_Type__c      True
# Business_Type__c          True
# Is_External__c            True
# ParentId                  True
# dtype: bool
# **************************** Describe *****************************
#                         Id    StageName Status_Reason__c    RecordType.Name  \
# count                 7597         7597             7288               7597
# unique                7597           18               25                 12
# top     0062e000002HG3mAAG  Closed Lost     Other (Lost)  Research Contract
# freq                     1         4003             2398               3453
#
#        RICE_Supported__c               CreatedDate CloseDate  \
# count               7569                      7597      7597
# unique                 4                      7498       885
# top             RIC-BD&I  2016-08-08T06:48:56.000Z   1/11/19
# freq                3289                        14      2726
#
#        Actual_Close_Date__c           AccountId     Lead_Faculty__c  \
# count                  6293                6840                6325
# unique                 1072                2408                  16
# top               11/5/2017  0012e000003A6qHAAS  0012e000002ZGfbAAG
# freq                    103                 324                1514
#
#             Lead_School__c Parent_Opportunity__c      RecordType.Name.1  \
# count                 4272                   982                   6840
# unique                  46                   315                      3
# top     0012e000002Zt0cAAC    0062e000002HFbAAAW  Business Organization
# freq                   526                    50                   6796
#
#         Industry Industry_Sub_Type__c                Business_Type__c  \
# count       6839                 4199                            6795
# unique        19                   19                              11
# top     Services            Education  Government: Australia: Federal
# freq        2457                 1366                            1419
#
#        Is_External__c            ParentId
# count            6840                1140
# unique              2                 105
# top          External  0012e000003A78yAAC
# freq             6796                 319

# %% [markdown]
# # Step 2: Data Cleaning

# %%
round(100*(lead.isnull().sum().sort_values(ascending=False)/len(lead.index)), 2)
# Out:
# Lead_School__c           43.30
# Lead_Faculty__c          17.28
# Status_Reason__c          4.47
# Business_Type__c          0.66
# RICE_Supported__c         0.41
# StageName                 0.00
# RecordType.Name           0.00
# CreatedDate               0.00
# CloseDate                 0.00
# Actual_Close_Date__c      0.00
# AccountId                 0.00
# CreatedMonth              0.00
# CreatedYear               0.00
# Parent_Opportunity__c     0.00
# RecordType.Name.1         0.00
# Industry                  0.00
# Industry_Sub_Type__c      0.00
# Is_External__c            0.00
# ParentId                  0.00
# CloseYear                 0.00
# CloseMonth                0.00
# Id                        0.00
# dtype: float64

# %% [markdown]
# ### Check if there are any duplicate values in the dataset

# %%
lead[lead.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Id, StageName, Status_Reason__c, RecordType.Name, RICE_Supported__c, CreatedDate, CloseDate, Actual_Close_Date__c, AccountId, Lead_Faculty__c, Lead_School__c, Parent_Opportunity__c, RecordType.Name.1, Industry, Industry_Sub_Type__c, Business_Type__c, Is_External__c, ParentId]
# Index: []

# %% [markdown]
# There are no duplicate values in the data.

# %% [markdown]
# ### (1) Transform to 1yes/0no

# %%
lead[["ParentId","Parent_Opportunity__c"]]=lead[["ParentId","Parent_Opportunity__c"]].notnull().astype(int)

# %%
lead[["Actual_Close_Date__c"]]=lead[["Actual_Close_Date__c"]].notnull().astype(int)

# %% [markdown]
# ### (2) Drop 3 columns

# %%
#lead = lead.drop(["Lead_School__c","Industry_Sub_Type__c"],axis=1)

# %%
#check null values
round(100*(lead.isnull().sum().sort_values(ascending=False)/len(lead.index)), 2)
# Out:
# Lead_School__c           43.30
# Lead_Faculty__c          17.28
# Business_Type__c          0.66
# StageName                 0.00
# Status_Reason__c          0.00
# RecordType.Name           0.00
# RICE_Supported__c         0.00
# CreatedDate               0.00
# CloseDate                 0.00
# Actual_Close_Date__c      0.00
# AccountId                 0.00
# CreatedMonth              0.00
# CreatedYear               0.00
# Parent_Opportunity__c     0.00
# RecordType.Name.1         0.00
# Industry                  0.00
# Industry_Sub_Type__c      0.00
# Is_External__c            0.00
# ParentId                  0.00
# CloseYear                 0.00
# CloseMonth                0.00
# Id                        0.00
# dtype: float64

# %% [markdown]
# ### (3) Delete opportunities without account id

# %%
lead.dropna(subset=['AccountId'],inplace=True)

# %%
round(100*(lead.isnull().sum().sort_values(ascending=False)/len(lead.index)), 2)
# Out:
# Lead_School__c           43.30
# Lead_Faculty__c          17.28
# Status_Reason__c          4.47
# Business_Type__c          0.66
# RICE_Supported__c         0.41
# StageName                 0.00
# RecordType.Name           0.00
# CreatedDate               0.00
# CloseDate                 0.00
# Actual_Close_Date__c      0.00
# AccountId                 0.00
# CreatedMonth              0.00
# CreatedYear               0.00
# Parent_Opportunity__c     0.00
# RecordType.Name.1         0.00
# Industry                  0.00
# Industry_Sub_Type__c      0.00
# Is_External__c            0.00
# ParentId                  0.00
# CloseYear                 0.00
# CloseMonth                0.00
# Id                        0.00
# dtype: float64

# %% [markdown]
# ### (4) CreatedDate, CloseDate change string to time, seperate year, month

# %%
lead.loc[:,"CloseDate"]
# Out:
# 0        31/8/20
# 1       31/12/49
# 2        22/6/20
# 3       31/12/49
# 4       31/12/49
#           ...
# 7591    30/10/20
# 7592     30/9/20
# 7593     30/9/20
# 7595    31/12/20
# 7596    30/11/20
# Name: CloseDate, Length: 6840, dtype: object

# %%
lead.loc[:,'CloseDate']=pd.to_datetime(lead.loc[:,'CloseDate'],
                                           format='%d/%m/%y', 
                                           errors='coerce')

# %%
lead['CloseYear'] = pd.DatetimeIndex(lead['CloseDate']).year  
lead.loc[:,"CloseYear"]
# Out:
# 0       2020
# 1       2049
# 2       2020
# 3       2049
# 4       2049
#         ...
# 7591    2020
# 7592    2020
# 7593    2020
# 7595    2020
# 7596    2020
# Name: CloseYear, Length: 6840, dtype: int64

# %%
lead['CloseMonth'] = pd.DatetimeIndex(lead['CloseDate']).month

# %%
lead.loc[:,"CreatedDate"]
# Out:
# 0       2019-11-07T00:59:46.000Z
# 1       2018-09-19T04:32:55.000Z
# 2       2018-09-19T04:32:19.000Z
# 3       2016-07-06T05:03:00.000Z
# 4       2016-07-21T23:56:54.000Z
#                   ...
# 7591    2020-08-06T00:24:37.000Z
# 7592    2020-08-06T01:33:22.000Z
# 7593    2020-08-06T01:40:55.000Z
# 7595    2020-08-06T11:13:34.000Z
# 7596    2020-08-06T14:36:01.000Z
# Name: CreatedDate, Length: 6840, dtype: object

# %%
lead['CreatedYear'] = pd.DatetimeIndex(lead['CreatedDate']).year

# %%
lead.loc[:,"CreatedYear"]
# Out:
# 0       2019
# 1       2018
# 2       2018
# 3       2016
# 4       2016
#         ...
# 7591    2020
# 7592    2020
# 7593    2020
# 7595    2020
# 7596    2020
# Name: CreatedYear, Length: 6840, dtype: int64

# %%
lead['CreatedMonth'] = pd.DatetimeIndex(lead['CreatedDate']).month

# %%
lead.loc[:,"CreatedMonth"]
# Out:
# 0       11
# 1        9
# 2        9
# 3        7
# 4        7
#         ..
# 7591     8
# 7592     8
# 7593     8
# 7595     8
# 7596     8
# Name: CreatedMonth, Length: 6840, dtype: int64

# %% [markdown]
# ### (5) Industry

# %%
lead['Industry'].value_counts()
# Out:
# Services                                    2457
# Health                                      1530
# Public Administration                        963
# Defence                                      477
# Technology: IT & Telephone Services          263
# Agriculture & Horticulture                   259
# Manufacturing & R&D                          212
# Energy & Utilities                           191
# Construction & Construction Materials        137
# Transportation & Logistics                   108
# Mining & Refining                             73
# Materials: Chemicals & Industrial Metals      50
# Education                                     44
# Veterinary                                    35
# Mining Equipment and Technology Services      17
# Transportation                                 8
# Aquaculture & Fisheries                        6
# Forestry & Paper                               6
# Advertising, Marketing and PR                  3
# Name: Industry, dtype: int64

# %%
lead['Industry'].isnull().sum()
# Out:
# 1

# %%
lead[lead['Industry'].isin([np.nan])]
# Out:
#                       Id    StageName          Status_Reason__c  \
# 5807  0062e000002JFzFAAW  Closed Lost  Academic Capacity (Lost)
#
#                  RecordType.Name RICE_Supported__c               CreatedDate  \
# 5807  Consultancy (Non-research)          RIC-BD&I  2019-12-10T03:10:48.000Z
#
#       CloseDate  Actual_Close_Date__c           AccountId Lead_Faculty__c  \
# 5807 2020-01-13                     1  0012e000003AAqGAAW             NaN
#
#       ... RecordType.Name.1  Industry Industry_Sub_Type__c Business_Type__c  \
# 5807  ...    Administrative       NaN                  NaN              NaN
#
#      Is_External__c ParentId CloseYear  CloseMonth  CreatedYear  CreatedMonth
# 5807       External        0      2020           1         2019            12
#
# [1 rows x 22 columns]

# %%
# since "Services" has the major chunk of data, 
# we can impute the null values with Services
lead['Industry'] = lead['Industry'].replace(np.nan, "Services")

# %% [markdown]
# ### (6) Industry_Sub_Type__c

# %%
#for row in lead[lead['Industry'].isin(["Public Administration"])]:
    #lead['Industry_Sub_Type__c'] = lead['Industry_Sub_Type__c'].replace(np.nan, "Public Administration")
    
lead["Industry_Sub_Type__c"].fillna(lead["Industry"], inplace=True)

# %% [markdown]
# ### (7) Status_Reason__c

# %%
#lead['Status_Reason__c'] = lead['Status_Reason__c'].replace(np.nan, "Other (Lost)")
lead[lead['Status_Reason__c'].isin([np.nan])]
# Out:
# Empty DataFrame
# Columns: [Id, StageName, Status_Reason__c, RecordType.Name, RICE_Supported__c, CreatedDate, CloseDate, Actual_Close_Date__c, AccountId, Lead_Faculty__c, Lead_School__c, Parent_Opportunity__c, RecordType.Name.1, Industry, Industry_Sub_Type__c, Business_Type__c, Is_External__c, ParentId, CloseYear, CloseMonth, CreatedYear, CreatedMonth]
# Index: []
#
# [0 rows x 22 columns]

# %%
lead["Status_Reason__c"].fillna(lead["StageName"], inplace=True)

# %% [markdown]
# ### (8) 'RICE_Supported__c'

# %%
lead['RICE_Supported__c'].value_counts()
# Out:
# RIC-BD&I             3289
# RIC RE&D and BD&I    3084
# Not supported         637
# RIC-RE&D              559
# Name: RICE_Supported__c, dtype: int64

# %%
lead[lead['RICE_Supported__c'].isin([np.nan])]
# Out:
#                     Id         StageName  Status_Reason__c RecordType.Name  \
# 3   0062e000002HFacAAG            Closed            Closed    Parent Grant
# 4   0062e000002HFadAAG            Closed            Closed    Parent Grant
# 5   0062e000002HFaeAAG            Closed            Closed    Parent Grant
# 6   0062e000002HFafAAG            Closed            Closed    Parent Grant
# 7   0062e000002HFagAAG            Closed            Closed    Parent Grant
# 8   0062e000002HFahAAG            Closed            Closed    Parent Grant
# 10  0062e000002HFajAAG            Closed            Closed    Parent Grant
# 11  0062e000002HFakAAG            Closed            Closed    Parent Grant
# 13  0062e000002HFamAAG            Closed            Closed    Parent Grant
# 14  0062e000002HFanAAG            Closed            Closed    Parent Grant
# 15  0062e000002HFaoAAG            Closed            Closed    Parent Grant
# 16  0062e000002HFapAAG            Closed            Closed    Parent Grant
# 17  0062e000002HFaqAAG            Closed            Closed    Parent Grant
# 18  0062e000002HFarAAG            Closed            Closed    Parent Grant
# 19  0062e000002HFasAAG            Closed            Closed    Parent Grant
# 20  0062e000002HFatAAG            Closed            Closed    Parent Grant
# 21  0062e000002HFauAAG        Submitting        Submitting    Parent Grant
# 25  0062e000002HFayAAG  Awaiting Results  Awaiting Results    Parent Grant
# 26  0062e000002HFazAAG            Closed            Closed    Parent Grant
# 29  0062e000002HFb1AAG            Closed            Closed    Parent Grant
# 30  0062e000002HFb2AAG            Closed            Closed    Parent Grant
# 33  0062e000002HFb5AAG            Closed            Closed    Parent Grant
# 35  0062e000002HFb7AAG            Closed            Closed    Parent Grant
# 36  0062e000002HFb8AAG            Closed            Closed    Parent Grant
# 42  0062e000002HFbEAAW  Awaiting Results  Awaiting Results    Parent Grant
# 43  0062e000002HFbFAAW        Submitting        Submitting    Parent Grant
# 44  0062e000002HFbGAAW        Submitting        Submitting    Parent Grant
# 48  0062e000002HFbKAAW        Submitting        Submitting    Parent Grant
#
#    RICE_Supported__c               CreatedDate  CloseDate  \
# 3                NaN  2016-07-06T05:03:00.000Z 2049-12-31
# 4                NaN  2016-07-21T23:56:54.000Z 2049-12-31
# 5                NaN  2017-04-07T01:30:10.000Z 2049-12-31
# 6                NaN  2017-06-27T01:24:02.000Z 2049-12-31
# 7                NaN  2017-11-27T22:16:34.000Z 2049-12-31
# 8                NaN  2016-08-22T01:40:33.000Z 2049-12-31
# 10               NaN  2017-12-15T01:48:39.000Z 2049-12-31
# 11               NaN  2017-02-14T00:14:42.000Z 2049-12-31
# 13               NaN  2017-04-07T04:48:26.000Z 2049-12-31
# 14               NaN  2016-09-20T00:32:03.000Z 2049-12-31
# 15               NaN  2016-11-30T04:37:19.000Z 2049-12-31
# 16               NaN  2017-03-16T23:51:33.000Z 2049-12-31
# 17               NaN  2017-03-16T23:50:50.000Z 2049-12-31
# 18               NaN  2017-03-16T23:49:13.000Z 2049-12-31
# 19               NaN  2016-10-05T23:33:53.000Z 2049-12-31
# 20               NaN  2016-07-04T06:55:46.000Z 2049-12-31
# 21               NaN  2019-06-03T00:03:32.000Z 2049-12-31
# 25               NaN  2019-06-13T11:30:14.000Z 2049-12-31
# 26               NaN  2019-03-05T02:36:30.000Z 2019-06-01
# 29               NaN  2017-10-05T02:38:18.000Z 2018-02-15
# 30               NaN  2017-10-04T23:42:59.000Z 2019-01-18
# 33               NaN  2019-03-07T04:28:26.000Z 2018-09-10
# 35               NaN  2019-04-18T05:24:33.000Z 2019-04-03
# 36               NaN  2019-04-09T00:38:20.000Z 2019-04-03
# 42               NaN  2019-07-09T06:50:40.000Z 2049-12-31
# 43               NaN  2019-05-15T04:26:53.000Z 2049-12-31
# 44               NaN  2019-05-15T04:28:26.000Z 2049-12-31
# 48               NaN  2019-04-03T22:58:54.000Z 2049-12-31
#
#     Actual_Close_Date__c           AccountId Lead_Faculty__c  ...  \
# 3                      1  0012e000003A6osAAC             NaN  ...
# 4                      1  0012e000003A79XAAS             NaN  ...
# 5                      1  0012e000003A79XAAS             NaN  ...
# 6                      1  0012e000003A6hbAAC             NaN  ...
# 7                      1  0012e000003A6jLAAS             NaN  ...
# 8                      1  0012e000003A6MsAAK             NaN  ...
# 10                     1  0012e000003A6bnAAC             NaN  ...
# 11                     1  0012e000003A6osAAC             NaN  ...
# 13                     1  0012e000003A6osAAC             NaN  ...
# 14                     1  0012e000003A6osAAC             NaN  ...
# 15                     1  0012e000003A6bnAAC             NaN  ...
# 16                     1  0012e000003A6rKAAS             NaN  ...
# 17                     1  0012e000003A6k7AAC             NaN  ...
# 18                     1  0012e000003A6cOAAS             NaN  ...
# 19                     1  0012e000003A6cOAAS             NaN  ...
# 20                     1  0012e000003A6osAAC             NaN  ...
# 21                     1  0012e000003A6W0AAK             NaN  ...
# 25                     1  0012e000003A6ElAAK             NaN  ...
# 26                     1  0012e000003A6bnAAC             NaN  ...
# 29                     1  0012e000003A6bnAAC             NaN  ...
# 30                     1  0012e000003A6bnAAC             NaN  ...
# 33                     1  0012e000003A6bnAAC             NaN  ...
# 35                     1  0012e000003A6oWAAS             NaN  ...
# 36                     1  0012e000003A6oWAAS             NaN  ...
# 42                     1  0012e000003A6ElAAK             NaN  ...
# 43                     1  0012e000003A6ElAAK             NaN  ...
# 44                     1  0012e000003A6ElAAK             NaN  ...
# 48                     1  0012e000003A6bnAAC             NaN  ...
#
#         RecordType.Name.1                    Industry  \
# 3   Business Organization       Public Administration
# 4   Business Organization       Public Administration
# 5   Business Organization       Public Administration
# 6   Business Organization          Energy & Utilities
# 7   Business Organization                      Health
# 8   Business Organization  Agriculture & Horticulture
# 10  Business Organization                      Health
# 11  Business Organization       Public Administration
# 13  Business Organization       Public Administration
# 14  Business Organization       Public Administration
# 15  Business Organization                      Health
# 16  Business Organization                      Health
# 17  Business Organization                      Health
# 18  Business Organization                      Health
# 19  Business Organization                      Health
# 20  Business Organization       Public Administration
# 21  Business Organization                      Health
# 25  Business Organization       Public Administration
# 26  Business Organization                      Health
# 29  Business Organization                      Health
# 30  Business Organization                      Health
# 33  Business Organization                      Health
# 35  Business Organization                      Health
# 36  Business Organization                      Health
# 42  Business Organization       Public Administration
# 43  Business Organization       Public Administration
# 44  Business Organization       Public Administration
# 48  Business Organization                      Health
#
#            Industry_Sub_Type__c                       Business_Type__c  \
# 3         Public Administration         Government: Australia: Federal
# 4         Public Administration         Government: Australia: Federal
# 5         Public Administration         Government: Australia: Federal
# 6         Public Administration         Government: Australia: Federal
# 7               Pharmaceuticals  Multinational / Other Large Corporate
# 8         Public Administration   Government: Australia: Local & State
# 10  Health Care & Healthy Aging         Government: Australia: Federal
# 11        Public Administration         Government: Australia: Federal
# 13        Public Administration         Government: Australia: Federal
# 14        Public Administration         Government: Australia: Federal
# 15  Health Care & Healthy Aging         Government: Australia: Federal
# 16              Pharmaceuticals       SME (small to medium enterprise)
# 17              Pharmaceuticals             Large Australian Corporate
# 18              Pharmaceuticals  Multinational / Other Large Corporate
# 19              Pharmaceuticals  Multinational / Other Large Corporate
# 20        Public Administration         Government: Australia: Federal
# 21  Health Care & Healthy Aging         Government: Australia: Federal
# 25        Public Administration         Government: Australia: Federal
# 26  Health Care & Healthy Aging         Government: Australia: Federal
# 29  Health Care & Healthy Aging         Government: Australia: Federal
# 30  Health Care & Healthy Aging         Government: Australia: Federal
# 33  Health Care & Healthy Aging         Government: Australia: Federal
# 35  Health Care & Healthy Aging                         Not for profit
# 36  Health Care & Healthy Aging                         Not for profit
# 42        Public Administration         Government: Australia: Federal
# 43        Public Administration         Government: Australia: Federal
# 44        Public Administration         Government: Australia: Federal
# 48  Health Care & Healthy Aging         Government: Australia: Federal
#
#    Is_External__c ParentId CloseYear  CloseMonth  CreatedYear  CreatedMonth
# 3        External        1      2049          12         2016             7
# 4        External        0      2049          12         2016             7
# 5        External        0      2049          12         2017             4
# 6        External        1      2049          12         2017             6
# 7        External        0      2049          12         2017            11
# 8        External        0      2049          12         2016             8
# 10       External        0      2049          12         2017            12
# 11       External        1      2049          12         2017             2
# 13       External        1      2049          12         2017             4
# 14       External        1      2049          12         2016             9
# 15       External        0      2049          12         2016            11
# 16       External        0      2049          12         2017             3
# 17       External        0      2049          12         2017             3
# 18       External        0      2049          12         2017             3
# 19       External        0      2049          12         2016            10
# 20       External        1      2049          12         2016             7
# 21       External        0      2049          12         2019             6
# 25       External        1      2049          12         2019             6
# 26       External        0      2019           6         2019             3
# 29       External        0      2018           2         2017            10
# 30       External        0      2019           1         2017            10
# 33       External        0      2018           9         2019             3
# 35       External        0      2019           4         2019             4
# 36       External        0      2019           4         2019             4
# 42       External        1      2049          12         2019             7
# 43       External        1      2049          12         2019             5
# 44       External        1      2049          12         2019             5
# 48       External        0      2049          12         2019             4
#
# [28 rows x 22 columns]

# %%
lead['RICE_Supported__c'] = lead['RICE_Supported__c'].replace(np.nan, "NotGiven")

# %% [markdown]
# ### (9) RecordType.Name.1

# %%
lead['RecordType.Name.1'].value_counts()
# Out:
# Business Organization    6796
# University Department      43
# Administrative              1
# Name: RecordType.Name.1, dtype: int64

# %%
lead[lead['RecordType.Name.1'].isin([np.nan])]
# Out:
# Empty DataFrame
# Columns: [Id, StageName, Status_Reason__c, RecordType.Name, RICE_Supported__c, CreatedDate, CloseDate, Actual_Close_Date__c, AccountId, Lead_Faculty__c, Lead_School__c, Parent_Opportunity__c, RecordType.Name.1, Industry, Industry_Sub_Type__c, Business_Type__c, Is_External__c, ParentId, CloseYear, CloseMonth, CreatedYear, CreatedMonth]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# ### (10) 'Business_Type__c'

# %%
lead['Business_Type__c'].value_counts()
# Out:
# Government: Australia: Federal                       1419
# Government: Australia: Local & State                 1288
# SME (small to medium enterprise)                      914
# Multinational / Other Large Corporate                 853
# Not for profit                                        823
# University                                            535
# Large Australian Corporate                            440
# Government: International                             321
# PFRO (Publicly-Funded Research Organisation)          101
# RDC (Rural Research and Development Corporations)      53
# CRC (Co-operative Research Centre)                     48
# Name: Business_Type__c, dtype: int64

# %%
lead[lead['Business_Type__c'].isin([np.nan])]
# Out:
#                       Id    StageName               Status_Reason__c  \
# 82    0062e000002HFtrAAG  Closed Lost                   Other (Lost)
# 84    0062e000002HFtsAAG  Closed Lost                   Other (Lost)
# 86    0062e000002HFttAAG  Closed Lost                   Other (Lost)
# 88    0062e000002HFtuAAG  Closed Lost                   Other (Lost)
# 90    0062e000002HFtvAAG  Closed Lost                   Other (Lost)
# 92    0062e000002HFtwAAG  Closed Lost                   Other (Lost)
# 94    0062e000002HFtxAAG  Closed Lost                   Other (Lost)
# 96    0062e000002HFtyAAG  Closed Lost                   Other (Lost)
# 98    0062e000002HFtzAAG  Closed Lost                   Other (Lost)
# 100   0062e000002HFu0AAG  Closed Lost                   Other (Lost)
# 101   0062e000002HFu1AAG  Closed Lost                   Other (Lost)
# 102   0062e000002HFu2AAG  Closed Lost                   Other (Lost)
# 103   0062e000002HFu3AAG  Closed Lost                   Other (Lost)
# 104   0062e000002HFu4AAG  Closed Lost                   Other (Lost)
# 195   0062e000002HFvLAAW  Closed Lost                   Other (Lost)
# 197   0062e000002HFvMAAW  Closed Lost                   Other (Lost)
# 198   0062e000002HFvnAAG  Closed Lost                   Other (Lost)
# 210   0062e000002HFvtAAG  Closed Lost                   Other (Lost)
# 295   0062e000002HFx9AAG  Closed Lost                   Other (Lost)
# 775   0062e000002HG5kAAG  Closed Lost                   Other (Lost)
# 813   0062e000002HG66AAG  Closed Lost                   Other (Lost)
# 814   0062e000002HG67AAG  Identifying       Awaiting Customer Action
# 1075  0062e000002HGaFAAW  Closed Lost                   Other (Lost)
# 1139  0062e000002HGAYAA4  Closed Lost                   Other (Lost)
# 1143  0062e000002HGAZAA4  Closed Lost                   Other (Lost)
# 1153  0062e000002HGb3AAG  Closed Lost                   Other (Lost)
# 1300  0062e000002HGCDAA4  Closed Lost                   Other (Lost)
# 1303  0062e000002HGCEAA4  Closed Lost                   Other (Lost)
# 1736  0062e000002HGg3AAG  Identifying                   Other (Lost)
# 1738  0062e000002HGg4AAG  Identifying                 Other IP Issue
# 2067  0062e000002HGIvAAO  Closed Lost  Customer No Longer Interested
# 2983  0062e000002HGqqAAG  Closed Lost                   Other (Lost)
# 2987  0062e000002HGqrAAG  Closed Lost                   Other (Lost)
# 3282  0062e000002HGt5AAG   Closed Won                            Won
# 3675  0062e000002HGwjAAG   Closed Won                            Won
# 4092  0062e000002HH0QAAW  Closed Lost                   Other (Lost)
# 4347  0062e000002HH53AAG   Closed Won                            Won
# 4870  0062e000002HHDQAA4   Closed Won                            Won
# 4997  0062e000002HHFrAAO   Closed Won                            Won
# 4999  0062e000002HHFsAAO   Closed Won                            Won
# 5001  0062e000002HHFtAAO  Closed Lost                   Other (Lost)
# 5147  0062e000002HHICAA4      Closing                       On Track
# 5338  0062e000002HHLKAA4   Closed Won                            Won
# 5807  0062e000002JFzFAAW  Closed Lost       Academic Capacity (Lost)
# 7459  0062e000002XzU5AAK   Closed Won                            Won
#
#                          RecordType.Name  RICE_Supported__c  \
# 82    Custom Education (MSPACE Included)  RIC RE&D and BD&I
# 84    Custom Education (MSPACE Included)  RIC RE&D and BD&I
# 86                     Research Contract  RIC RE&D and BD&I
# 88    Custom Education (MSPACE Included)      Not supported
# 90    Custom Education (MSPACE Included)  RIC RE&D and BD&I
# 92    Custom Education (MSPACE Included)      Not supported
# 94    Custom Education (MSPACE Included)  RIC RE&D and BD&I
# 96    Custom Education (MSPACE Included)  RIC RE&D and BD&I
# 98    Custom Education (MSPACE Included)  RIC RE&D and BD&I
# 100                           Internship  RIC RE&D and BD&I
# 101           Consultancy (Non-research)  RIC RE&D and BD&I
# 102                    Research Contract  RIC RE&D and BD&I
# 103           Consultancy (Non-research)  RIC RE&D and BD&I
# 104   Custom Education (MSPACE Included)  RIC RE&D and BD&I
# 195                  Technology Transfer  RIC RE&D and BD&I
# 197                  Technology Transfer  RIC RE&D and BD&I
# 198   Custom Education (MSPACE Included)           RIC-BD&I
# 210   Custom Education (MSPACE Included)           RIC-BD&I
# 295                    Research Contract  RIC RE&D and BD&I
# 775   Custom Education (MSPACE Included)           RIC-BD&I
# 813                  Technology Transfer           RIC-BD&I
# 814                  Technology Transfer           RIC-BD&I
# 1075                   Research Contract  RIC RE&D and BD&I
# 1139                              Grants           RIC-RE&D
# 1143                              Grants           RIC-RE&D
# 1153                   Research Contract  RIC RE&D and BD&I
# 1300                   Research Contract           RIC-BD&I
# 1303                   Research Contract           RIC-BD&I
# 1736                 Technology Transfer           RIC-BD&I
# 1738                 Technology Transfer           RIC-BD&I
# 2067  Custom Education (MSPACE Included)           RIC-BD&I
# 2983                   Research Contract  RIC RE&D and BD&I
# 2987                   Research Contract  RIC RE&D and BD&I
# 3282                 Technology Transfer  RIC RE&D and BD&I
# 3675                 Technology Transfer  RIC RE&D and BD&I
# 4092                   Research Contract  RIC RE&D and BD&I
# 4347                   Research Contract  RIC RE&D and BD&I
# 4870                              Grants  RIC RE&D and BD&I
# 4997                   Research Contract  RIC RE&D and BD&I
# 4999                   Research Contract  RIC RE&D and BD&I
# 5001                              Grants  RIC RE&D and BD&I
# 5147                   Research Contract           RIC-BD&I
# 5338          Consultancy (Non-research)  RIC RE&D and BD&I
# 5807          Consultancy (Non-research)           RIC-BD&I
# 7459                   Research Contract           RIC-BD&I
#
#                    CreatedDate  CloseDate  Actual_Close_Date__c  \
# 82    2016-06-01T06:31:24.000Z 2019-11-01                     1
# 84    2017-05-09T06:26:42.000Z 2019-11-01                     1
# 86    2016-06-01T06:17:28.000Z 2019-11-01                     1
# 88    2018-01-22T00:12:49.000Z 2019-11-01                     1
# 90    2017-04-28T04:09:27.000Z 2019-11-01                     1
# 92    2018-01-22T00:11:00.000Z 2019-11-01                     1
# 94    2017-08-27T10:47:44.000Z 2019-11-01                     1
# 96    2016-02-03T22:45:38.000Z 2019-11-01                     1
# 98    2017-10-23T22:54:26.000Z 2019-11-01                     1
# 100   2016-06-01T11:24:39.000Z 2019-11-01                     1
# 101   2017-09-26T11:11:45.000Z 2019-11-01                     1
# 102   2016-06-01T11:25:43.000Z 2019-11-01                     1
# 103   2016-06-01T11:28:41.000Z 2019-11-01                     1
# 104   2016-06-01T11:33:42.000Z 2019-11-01                     1
# 195   2016-05-30T04:14:17.000Z 2019-11-01                     1
# 197   2015-10-21T01:26:41.000Z 2019-11-01                     1
# 198   2017-09-15T03:09:37.000Z 2020-04-30                     1
# 210   2017-09-14T04:51:24.000Z 2020-05-29                     1
# 295   2017-03-12T09:16:15.000Z 2019-11-01                     1
# 775   2018-06-11T23:42:11.000Z 2018-11-29                     1
# 813   2017-01-12T06:35:28.000Z 2019-11-01                     1
# 814   2018-09-17T08:14:12.000Z 2020-11-30                     1
# 1075  2015-12-22T22:02:03.000Z 2019-11-01                     1
# 1139  2018-04-24T05:35:16.000Z 2019-11-01                     1
# 1143  2018-04-17T00:48:29.000Z 2019-11-01                     1
# 1153  2015-12-09T22:50:02.000Z 2019-11-01                     1
# 1300  2016-04-07T03:47:09.000Z 2019-11-01                     1
# 1303  2016-08-10T05:17:26.000Z 2019-11-01                     1
# 1736  2019-03-25T04:47:44.000Z 2020-12-24                     1
# 1738  2018-07-26T08:55:17.000Z 2020-12-24                     1
# 2067  2017-02-07T00:37:03.000Z 2020-11-26                     1
# 2983  2015-10-25T05:13:03.000Z 2015-12-31                     1
# 2987  2015-10-25T06:28:54.000Z 2015-12-31                     1
# 3282  2018-02-12T19:41:32.000Z 2018-04-13                     1
# 3675  2017-12-01T02:36:21.000Z 2019-11-01                     1
# 4092  2016-02-14T23:28:42.000Z 2019-11-01                     1
# 4347  2017-07-28T03:11:04.000Z 2019-11-01                     1
# 4870  2016-02-29T08:03:04.000Z 2019-11-01                     1
# 4997  2016-11-05T05:32:28.000Z 2019-11-01                     1
# 4999  2015-12-21T11:52:50.000Z 2016-03-31                     1
# 5001  2016-05-06T04:02:14.000Z 2019-11-01                     1
# 5147  2019-06-03T10:22:01.000Z 2020-12-31                     1
# 5338  2017-07-18T02:26:11.000Z 2019-11-01                     1
# 5807  2019-12-10T03:10:48.000Z 2020-01-13                     1
# 7459  2020-07-16T06:44:43.000Z 2020-07-31                     1
#
#                AccountId     Lead_Faculty__c  ...      RecordType.Name.1  \
# 82    0012e000002YmNRAA0  0012e000002ZNYOAA4  ...  University Department
# 84    0012e000002YmNRAA0  0012e000002ZNYOAA4  ...  University Department
# 86    0012e000002Z4IxAAK  0012e000002ZNYOAA4  ...  University Department
# 88    0012e000002Z3OuAAK  0012e000002ZNYOAA4  ...  University Department
# 90    0012e000002YlvyAAC  0012e000002ZNYOAA4  ...  University Department
# 92    0012e000002YlvyAAC  0012e000002ZNYOAA4  ...  University Department
# 94    0012e000002Z4IxAAK  0012e000002ZNYOAA4  ...  University Department
# 96    0012e000002Z3OuAAK  0012e000002ZNYOAA4  ...  University Department
# 98    0012e000002ZNYOAA4  0012e000002ZNYOAA4  ...  University Department
# 100   0012e000002YlvyAAC  0012e000002ZNYOAA4  ...  University Department
# 101   0012e000002Z4oNAAS  0012e000002ZNYOAA4  ...  University Department
# 102   0012e000002YlvyAAC  0012e000002ZNYOAA4  ...  University Department
# 103   0012e000002YlvyAAC  0012e000002ZNYOAA4  ...  University Department
# 104   0012e000002YlvyAAC  0012e000002ZNYOAA4  ...  University Department
# 195   0012e000002Zmo0AAC  0012e000002Zmo0AAC  ...  University Department
# 197   0012e000002Zmo0AAC  0012e000002Zmo0AAC  ...  University Department
# 198   0012e000002Zt0oAAC  0012e000002ZGfbAAG  ...  University Department
# 210   0012e000002Zt0oAAC  0012e000002ZGfbAAG  ...  University Department
# 295   0012e000002ZGfbAAG  0012e000002ZGfbAAG  ...  University Department
# 775   0012e000002Z3pPAAS  0012e000002ZLg7AAG  ...  University Department
# 813   0012e000002Zt1lAAC  0012e000002ZLg7AAG  ...  University Department
# 814   0012e000002Zt1lAAC  0012e000002ZLg7AAG  ...  University Department
# 1075  0012e000002ZmnzAAC                 NaN  ...  University Department
# 1139  0012e000002Zt0hAAC  0012e000002ZGfbAAG  ...  University Department
# 1143  0012e000002Zt21AAC  0012e000002ZGfbAAG  ...  University Department
# 1153  0012e000002Zt0lAAC                 NaN  ...  University Department
# 1300  0012e000002Z51eAAC  0012e000002ZmOZAA0  ...  University Department
# 1303  0012e000002ZLgBAAW  0012e000002ZmOZAA0  ...  University Department
# 1736  0012e000002Zt1lAAC  0012e000003hllpAAA  ...  University Department
# 1738  0012e000002Zt1lAAC  0012e000002ZGfbAAG  ...  University Department
# 2067  0012e000002Zmo0AAC  0012e000002Zmo0AAC  ...  University Department
# 2983  0012e000002YnrYAAS                 NaN  ...  University Department
# 2987  0012e000002Z3OuAAK                 NaN  ...  University Department
# 3282  0012e0000036xSkAAI  0012e000002ZLg7AAG  ...  University Department
# 3675  0012e000002Zt1lAAC  0012e000002ZGfbAAG  ...  University Department
# 4092  0012e000002Zt0tAAC                 NaN  ...  University Department
# 4347  0012e000002Zt1lAAC  0012e000002ZGfbAAG  ...  University Department
# 4870  0012e0000036xT0AAI  0012e000002ZGfbAAG  ...  University Department
# 4997  0012e000002Zt0yAAC  0012e000002ZGfbAAG  ...  University Department
# 4999  0012e000002Zt0yAAC  0012e000002ZGfbAAG  ...  University Department
# 5001  0012e000002Zt0nAAC                 NaN  ...  University Department
# 5147  0012e000002Z3pPAAS  0012e000002ZmOZAA0  ...  University Department
# 5338  0012e000002Zt0lAAC  0012e000002ZLg7AAG  ...  University Department
# 5807  0012e000003AAqGAAW                 NaN  ...         Administrative
# 7459  0012e0000037tS3AAI  0012e000002ZGfbAAG  ...  Business Organization
#
#        Industry   Industry_Sub_Type__c Business_Type__c Is_External__c  \
# 82    Education  Public Administration              NaN       Internal
# 84    Education  Public Administration              NaN       Internal
# 86    Education  Public Administration              NaN       Internal
# 88    Education  Public Administration              NaN       Internal
# 90    Education  Public Administration              NaN       Internal
# 92    Education  Public Administration              NaN       Internal
# 94    Education  Public Administration              NaN       Internal
# 96    Education  Public Administration              NaN       Internal
# 98    Education  Public Administration              NaN       Internal
# 100   Education  Public Administration              NaN       Internal
# 101   Education  Public Administration              NaN       Internal
# 102   Education  Public Administration              NaN       Internal
# 103   Education  Public Administration              NaN       Internal
# 104   Education  Public Administration              NaN       Internal
# 195   Education  Public Administration              NaN       Internal
# 197   Education  Public Administration              NaN       Internal
# 198   Education  Public Administration              NaN       Internal
# 210   Education  Public Administration              NaN       Internal
# 295   Education  Public Administration              NaN       Internal
# 775   Education  Public Administration              NaN       Internal
# 813   Education  Public Administration              NaN       Internal
# 814   Education  Public Administration              NaN       Internal
# 1075  Education  Public Administration              NaN       Internal
# 1139  Education  Public Administration              NaN       Internal
# 1143  Education  Public Administration              NaN       Internal
# 1153  Education  Public Administration              NaN       Internal
# 1300  Education  Public Administration              NaN       Internal
# 1303  Education  Public Administration              NaN       Internal
# 1736  Education  Public Administration              NaN       Internal
# 1738  Education  Public Administration              NaN       Internal
# 2067  Education  Public Administration              NaN       Internal
# 2983  Education  Public Administration              NaN       Internal
# 2987  Education  Public Administration              NaN       Internal
# 3282  Education  Public Administration              NaN       Internal
# 3675  Education  Public Administration              NaN       Internal
# 4092  Education  Public Administration              NaN       Internal
# 4347  Education  Public Administration              NaN       Internal
# 4870  Education  Public Administration              NaN       Internal
# 4997  Education  Public Administration              NaN       Internal
# 4999  Education  Public Administration              NaN       Internal
# 5001  Education  Public Administration              NaN       Internal
# 5147  Education  Public Administration              NaN       Internal
# 5338  Education  Public Administration              NaN       Internal
# 5807   Services  Public Administration              NaN       External
# 7459  Education  Public Administration              NaN       Internal
#
#      ParentId CloseYear  CloseMonth  CreatedYear  CreatedMonth
# 82          1      2019          11         2016             6
# 84          1      2019          11         2017             5
# 86          1      2019          11         2016             6
# 88          1      2019          11         2018             1
# 90          1      2019          11         2017             4
# 92          1      2019          11         2018             1
# 94          1      2019          11         2017             8
# 96          1      2019          11         2016             2
# 98          1      2019          11         2017            10
# 100         1      2019          11         2016             6
# 101         1      2019          11         2017             9
# 102         1      2019          11         2016             6
# 103         1      2019          11         2016             6
# 104         1      2019          11         2016             6
# 195         1      2019          11         2016             5
# 197         1      2019          11         2015            10
# 198         1      2020           4         2017             9
# 210         1      2020           5         2017             9
# 295         1      2019          11         2017             3
# 775         1      2018          11         2018             6
# 813         1      2019          11         2017             1
# 814         1      2020          11         2018             9
# 1075        1      2019          11         2015            12
# 1139        1      2019          11         2018             4
# 1143        1      2019          11         2018             4
# 1153        1      2019          11         2015            12
# 1300        1      2019          11         2016             4
# 1303        1      2019          11         2016             8
# 1736        1      2020          12         2019             3
# 1738        1      2020          12         2018             7
# 2067        1      2020          11         2017             2
# 2983        1      2015          12         2015            10
# 2987        1      2015          12         2015            10
# 3282        1      2018           4         2018             2
# 3675        1      2019          11         2017            12
# 4092        1      2019          11         2016             2
# 4347        1      2019          11         2017             7
# 4870        1      2019          11         2016             2
# 4997        1      2019          11         2016            11
# 4999        1      2016           3         2015            12
# 5001        1      2019          11         2016             5
# 5147        1      2020          12         2019             6
# 5338        1      2019          11         2017             7
# 5807        0      2020           1         2019            12
# 7459        0      2020           7         2020             7
#
# [45 rows x 22 columns]

# %%
lead['Business_Type__c'] = lead['Business_Type__c'].replace(np.nan, "Not for profit")

# %% [markdown]
# ### (11) 'Lead_Faculty__c','Lead_School__c'

# %%
lead['Lead_Faculty__c'] = lead['Lead_Faculty__c'].replace(np.nan, 'NotGiven')
lead['Lead_School__c'] = lead['Lead_School__c'].replace(np.nan, 'NotGiven')
#lead['Lead_Faculty__c'].value_counts()
round(100*(lead.isnull().sum().sort_values(ascending=False)/len(lead.index)), 2)
# Out:
# CreatedMonth             0.0
# CreatedYear              0.0
# StageName                0.0
# Status_Reason__c         0.0
# RecordType.Name          0.0
# RICE_Supported__c        0.0
# CreatedDate              0.0
# CloseDate                0.0
# Actual_Close_Date__c     0.0
# AccountId                0.0
# Lead_Faculty__c          0.0
# Lead_School__c           0.0
# Parent_Opportunity__c    0.0
# RecordType.Name.1        0.0
# Industry                 0.0
# Industry_Sub_Type__c     0.0
# Business_Type__c         0.0
# Is_External__c           0.0
# ParentId                 0.0
# CloseYear                0.0
# CloseMonth               0.0
# Id                       0.0
# dtype: float64

# %% [markdown]
# ### (12) StageName

# %%
lead['Status_Reason__c'].value_counts()
# Out:
# Other (Lost)                         1985
# Won                                  1984
# On Track                              802
# Customer No Longer Interested         607
# Proposal/Application Unsuccessful     434
# Academic Capacity (Lost)              198
# Out-Sold                              133
# Pre-submission                        100
# Awaiting Customer Action               90
# Customer Not Responding                87
# Academic No Longer Interested          70
# Awaiting Results                       63
# Closed                                 56
# Not Ready for Market                   40
# Submitting                             32
# Post Award                             27
# Closed Lost                            20
# BD Capacity (Lost)                     13
# Failure to Agree - Price               13
# Failure to Agree - Scope of Work       13
# Academic Capacity (Open)               10
# Unacceptable Risk                       9
# Other (Open)                            8
# Price                                   8
# Other IP Issue                          7
# Risk                                    7
# Scope of Proposal                       6
# Closed Won                              6
# Failure to Agree - IP terms             5
# IP Issue                                3
# Proposing                               1
# BD Capacity (Open)                      1
# Missed Milestone Date                   1
# Closing                                 1
# Name: Status_Reason__c, dtype: int64

# %%
lead['StageName'].value_counts()
# Out:
# Closed Lost                                  3389
# Closed Won                                   1733
# Identifying                                   404
# Developing                                    286
# Awaiting Results                              239
# Proposing                                     226
# Closing                                       148
# Application                                   115
# Pre-submission                                104
# Closed                                         56
# Execution / Closing                            33
# Submitting                                     32
# Execute Contract                               30
# Develop Relationship/ Qualify opportunity      18
# Notice                                         14
# Negotiation / Propose                           7
# Triage / Develop Opportunity                    6
# Name: StageName, dtype: int64

# %%
lead[lead['StageName'].isin(["Closed Won"])].count()/(len(lead.index))
# Out:
# Id                       0.249415
# StageName                0.249415
# Status_Reason__c         0.249415
# RecordType.Name          0.249415
# RICE_Supported__c        0.249415
# CreatedDate              0.249415
# CloseDate                0.249415
# Actual_Close_Date__c     0.249415
# AccountId                0.249415
# Lead_Faculty__c          0.249415
# Lead_School__c           0.249415
# Parent_Opportunity__c    0.249415
# RecordType.Name.1        0.249415
# Industry                 0.249415
# Industry_Sub_Type__c     0.249415
# Business_Type__c         0.249415
# Is_External__c           0.249415
# ParentId                 0.249415
# CloseYear                0.249415
# CloseMonth               0.249415
# CreatedYear              0.249415
# CreatedMonth             0.249415
# dtype: float64

# %% [markdown]
# Converted rate was 0.25

# %%
lead['StageName'] = lead['StageName'].replace('Post Award', "Closed Won")

# %%
lead['StageName'] = lead['StageName'].replace('Application', "Closed Won")

# %%
lead.loc[(lead['Status_Reason__c'] == 'Won')|(lead['Status_Reason__c'] == 'Post Award')|(lead['Status_Reason__c'] == 'Closed Won'), 'StageName'] = 'Closed Won'

# %%
lead[lead['StageName'].isin(["Closed Won"])].count()/(len(lead.index))
# Out:
# Id                       0.311257
# StageName                0.311257
# Status_Reason__c         0.311257
# RecordType.Name          0.311257
# RICE_Supported__c        0.311257
# CreatedDate              0.311257
# CloseDate                0.311257
# Actual_Close_Date__c     0.311257
# AccountId                0.311257
# Lead_Faculty__c          0.311257
# Lead_School__c           0.311257
# Parent_Opportunity__c    0.311257
# RecordType.Name.1        0.311257
# Industry                 0.311257
# Industry_Sub_Type__c     0.311257
# Business_Type__c         0.311257
# Is_External__c           0.311257
# ParentId                 0.311257
# CloseYear                0.311257
# CloseMonth               0.311257
# CreatedYear              0.311257
# CreatedMonth             0.311257
# dtype: float64

# %% [markdown]
# converted 0.31

# %%
#only closed won closed loss is remained

#lead['StageName'] = lead['StageName'].replace('Post Award', "Closed Won")



#data = lead.values
#print(len(data))
#new_data=[]

#for row in lead.values:
#    if row[2] == 'Won' or row[1]=='Post Award':#closing,developing, waiting result, proposing, iden
#        row[1] = 'Closed Won'
        
#    elif row[2] == 'Academic Capacity \(Lost\)' or row[2]=='Other \(Lost\)' or row[2] == "Customer No Longer Interested":
#        row[1] = 'Closed Lost'


#for row in data:
#    if row[1] == "Closed Lost" or row[1] != "Closed Won":
#        new_data.append(row)

#print(len(new_data))

#lead.values = new_data

#print(lead)
#print(lead.keys)

# %%
lead.to_csv("cleaned.csv",index=False)

# %%
#from google.colab import files
#uploaded = files.upload()

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from matplotlib import style
import matplotlib.pyplot as plt
import random
import torch
from torch.autograd import Variable
import torch.nn.functional as F
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
import pickle
import copy
style.use("ggplot")

def plot(train_rolling_loss,dev_rolling_loss,train_rolling_acc,dev_rolling_acc):
    plt.figure(figsize=(15,10))
    plt.subplot(221)
    plt.plot(train_rolling_loss,label="training")
    plt.plot(dev_rolling_loss,label="dev")
    plt.title("Rolling Loss",loc='center')
    plt.legend(loc=1)
    plt.subplot(222)
    plt.plot(train_rolling_acc,label="training")
    plt.plot(dev_rolling_acc,label="dev")
    plt.title("Rolling Accuracy",loc='center')
    plt.legend(loc=0)
    plt.show()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.cuda.device_count()
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# # 1. Pre-process dataset

# %%
## reading clean data
raw = pd.read_csv('cleaned-16-Oct.csv')
raw = raw.drop(['oppo_busi','fac_oppo', 'oppo_Industry'],axis=1)
raw.describe()
# Out:
#          StageName  Parent_Opportunity__c  Is_External__c     ParentId  \
# count  5408.000000            5408.000000     5408.000000  5408.000000
# mean      0.373706               0.098743        0.992604     0.162722
# std       0.483832               0.298344        0.085692     0.369146
# min       0.000000               0.000000        0.000000     0.000000
# 25%       0.000000               0.000000        1.000000     0.000000
# 50%       0.000000               0.000000        1.000000     0.000000
# 75%       1.000000               0.000000        1.000000     0.000000
# max       1.000000               1.000000        1.000000     1.000000
#
#        tasks_events  CreatedYear  CreatedMonth          days          RN  \
# count   5408.000000  5408.000000    5408.00000   5408.000000  5408.00000
# mean       0.063609  2017.855954       6.32304    470.180288    23.11372
# std        0.244079     1.308152       3.19268    519.571149    49.01797
# min        0.000000  2015.000000       1.00000   -426.000000     1.00000
# 25%        0.000000  2017.000000       4.00000     87.000000     1.00000
# 50%        0.000000  2018.000000       6.00000    333.000000     2.00000
# 75%        0.000000  2019.000000       9.00000    826.000000    15.00000
# max        1.000000  2020.000000      12.00000  11618.000000   279.00000
#
#        f_won_before
# count   5408.000000
# mean       0.457101
# std        0.498202
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
raw["StageName"].value_counts(dropna=False)
# Out:
# 0    3387
# 1    2021
# Name: StageName, dtype: int64

# %%
data = pd.concat([raw, raw[raw["StageName"]==1]], axis=0, ignore_index=True)
data["StageName"].value_counts(dropna=False).plot(kind="barh")
from sklearn.utils import shuffle
data = shuffle(data)

# %% [markdown]
# ## 1.2 One-Hot-Encoding

# %%
## one-hot-encoding

a = pd.get_dummies(data["RecordType.Name"], prefix='RecordType')
b = pd.get_dummies(data["RICE_Supported__c"], prefix='RICE_Supported')
c = pd.get_dummies(data["Lead_Faculty__c"], prefix='Lead_Faculty')
d = pd.get_dummies(data["Lead_School__c"], prefix='Lead_School')
e = pd.get_dummies(data["Industry"], prefix='Industry')
f = pd.get_dummies(data["Industry_Sub_Type__c"], prefix='Industry_Sub')
g = pd.get_dummies(data["Business_Type__c"], prefix='Business')

org = data[["StageName","Parent_Opportunity__c","Is_External__c","ParentId","f_won_before"]]

scale3 = data["CreatedYear"].div(2020)
scale4 = data["CreatedMonth"].div(12)
scale5 = data["days"].div(11618)
scale6 = data["RN"].div(279)

#df = pd.concat([org,scale3,scale4,scale5,scale6,a,b,c,d,e,f,g], axis=1, ignore_index=True)
df = pd.concat([org,scale3,scale4,scale5,scale6], axis=1, ignore_index=True)
df
# Out:
#       0  1  2  3  4         5         6         7         8
# 3998  1  0  1  0  1  0.998515  1.000000  0.058702  0.039427
# 5794  1  0  1  0  0  0.998515  0.666667  0.068773  0.003584
# 98    0  0  1  0  0  0.999010  0.583333  0.003873  0.003584
# 2743  0  0  1  0  0  0.999505  0.833333  0.000861  0.003584
# 2320  0  0  1  1  1  0.999505  0.250000  0.004390  0.046595
# ...  .. .. .. .. ..       ...       ...       ...       ...
# 5817  1  0  1  0  0  0.998020  0.416667  0.108194  0.003584
# 1496  0  0  1  0  0  0.999505  0.416667  0.020658  0.003584
# 2802  0  0  1  0  0  0.999010  0.250000  0.050697  0.003584
# 6508  1  1  1  0  1  0.999505  0.666667  0.014288  0.007168
# 673   0  0  1  0  0  0.997525  0.833333  0.126872  0.003584
#
# [7429 rows x 9 columns]

# %%
# split xy
x = torch.Tensor([i[1:] for i in df.values.tolist()])
y = torch.Tensor([i[0] for i in df.values.tolist()])

# train/dev split
batch_size = 64+16
x_train, x_dev, y_train, y_dev = train_test_split(x, y, test_size=0.33, random_state=42)
train_loader = torch.utils.data.DataLoader(dataset=tuple(zip(x_train,y_train)), batch_size=batch_size, shuffle=True)
dev_loader = torch.utils.data.DataLoader(dataset=tuple(zip(x_dev,y_dev)), batch_size=batch_size, shuffle=True)

# %%
n_features, n_classes = int(x_train.shape[1]), 1

# %% [markdown]
# # 2. Neural Network Model

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score

class Net(torch.nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.linear1 = torch.nn.Linear(n_features,1024)
        self.linear2 = torch.nn.Linear(1024, 1024)
        self.linear3 = torch.nn.Linear(1024, 1024)
        self.linear4 = torch.nn.Linear(1024, 1024)
        self.linear5 = torch.nn.Linear(1024, 1024)
        self.linear6 = torch.nn.Linear(1024, 1024)
        self.linear7 = torch.nn.Linear(1024, n_classes)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        x = F.relu(self.linear3(x))
        x = F.relu(self.linear4(x))
        x = F.relu(self.linear5(x))
        x = F.relu(self.linear6(x))
        x = F.relu(self.linear7(x))
        return x
    
def eval_metrics(raw_output,labels):
    outputs = torch.round(torch.sigmoid(raw_output)).detach()
    
    target_true = torch.sum(labels == 1).float()
    predicted_true = torch.sum(outputs).float()
    correct_true = torch.sum(labels * outputs).float()
    
    accuracy = torch.mean(torch.eq(outputs, labels).float()).item()
    precision = correct_true / (predicted_true)
    recall = correct_true / target_true
    
    return accuracy, precision.cpu().item(), recall.cpu().item()


def eval_metrics(raw_output,labels):
    outputs = torch.round(torch.sigmoid(raw_output)).detach()
    accuracy = accuracy_score(labels.detach().numpy(), outputs.numpy())
    precision = precision_score(labels.detach().numpy(), outputs.numpy())
    recall = recall_score(labels.detach().numpy(), outputs.numpy())
    return accuracy, precision, recall


def test_net(test_loader):
    test_loss,test_acc,test_prec,test_rec = 0.,0.,0.,0.
    scale = len(test_loader)
    
    for features, labels in test_loader:
        features = Variable(features).to(device)
        labels = Variable(labels).to(device)
        outputs = model(features)
        loss = criterion(outputs, labels.unsqueeze(1))
        test_loss += loss.item()

        a,b,c = eval_metrics(outputs,labels)
        test_acc += a
        test_prec += b
        test_rec += c
        
    return test_acc/scale, test_prec/scale, test_rec/scale, test_loss/scale


def train_net(train_loader,dev_loader,lr_rate):
    train_rolling_loss,dev_rolling_loss,train_rolling_acc,dev_rolling_acc = [],[],[],[]
    test_precision,test_recall = [],[]

    for epoch in range(int(epochs)):
        train_loss,train_acc = 0.,0.
        
        for i, (features, labels) in enumerate(train_loader):
            features = Variable(features).to(device)
            labels = Variable(labels).to(device)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels.unsqueeze(1))
            
            train_loss += loss.item()
            acc,_,_ = eval_metrics(outputs,labels)
            train_acc += acc
            
            loss.backward()
            optimizer.step()
            
        
        train_rolling_acc.append(train_acc/len(train_loader))
        train_rolling_loss.append(train_loss/len(train_loader))

        ## Development Dataset
        dev_acc,precision,recall,dev_loss = test_net(dev_loader)
        dev_rolling_acc.append(dev_acc)
        test_precision.append(precision)
        test_recall.append(recall)
        dev_rolling_loss.append(dev_loss)
        
        print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch, train_loss/len(train_loader)))
        
    print("Train Loss:\t",round(train_rolling_loss[-1],5),", \tTest Loss:\t",round(dev_rolling_loss[-1],5))
    print("Train Accuracy:\t",round(train_rolling_acc[-1],5),", \tTest Accuracy:\t",round(dev_rolling_acc[-1],5))
    print("Precision:\t",round(test_precision[-1],5),", \tRecall:\t",round(test_recall[-1],5))
    
    plot(train_rolling_loss,dev_rolling_loss,train_rolling_acc,dev_rolling_acc)
    
    plt.figure(figsize=(15,10))
    plt.subplot(221)
    plt.plot(test_precision,label="training")
    plt.subplot(222)
    plt.plot(test_recall,label="training")
    plt.show()
    
    return dev_rolling_loss,dev_rolling_acc,test_precision,test_recall

# %%
model = Net()
init_state = copy.deepcopy(model.state_dict())
criterion = torch.nn.BCEWithLogitsLoss() # BCELoss

# %%
epochs = 10
lr_rate = 0.00001
optimizer = torch.optim.Adam(model.parameters(), lr=lr_rate)
init_state_opt = copy.deepcopy(optimizer.state_dict())

# %%
#### RUN MODEL
epochs = 200
model.load_state_dict(init_state)
optimizer.load_state_dict(init_state_opt)
model.to(device)
results = train_net(train_loader,dev_loader,lr_rate)
# Out:
# Epoch: 0 	Training Loss: 0.689545
# Epoch: 1 	Training Loss: 0.681951
# Epoch: 2 	Training Loss: 0.672120
# Epoch: 3 	Training Loss: 0.667396
# Epoch: 4 	Training Loss: 0.666767
# Epoch: 5 	Training Loss: 0.668059
# Epoch: 6 	Training Loss: 0.666371
# Epoch: 7 	Training Loss: 0.665089
# Epoch: 8 	Training Loss: 0.666175
# Epoch: 9 	Training Loss: 0.664753
# Epoch: 10 	Training Loss: 0.664467
# Epoch: 11 	Training Loss: 0.666219
# Epoch: 12 	Training Loss: 0.664893
# Epoch: 13 	Training Loss: 0.665654
# Epoch: 14 	Training Loss: 0.664774
# Epoch: 15 	Training Loss: 0.664844
# Epoch: 16 	Training Loss: 0.663813
# Epoch: 17 	Training Loss: 0.664240
# Epoch: 18 	Training Loss: 0.662980
# Epoch: 19 	Training Loss: 0.665172
# Epoch: 20 	Training Loss: 0.664259
# Epoch: 21 	Training Loss: 0.663151
# Epoch: 22 	Training Loss: 0.663439
# Epoch: 23 	Training Loss: 0.664136
# Epoch: 24 	Training Loss: 0.663905
# Epoch: 25 	Training Loss: 0.664024
# Epoch: 26 	Training Loss: 0.662832
# Epoch: 27 	Training Loss: 0.663032
# Epoch: 28 	Training Loss: 0.663472
# Epoch: 29 	Training Loss: 0.662903
# Epoch: 30 	Training Loss: 0.662723
# Epoch: 31 	Training Loss: 0.662294
# Epoch: 32 	Training Loss: 0.663045
# Epoch: 33 	Training Loss: 0.662034
# Epoch: 34 	Training Loss: 0.662056
# Epoch: 35 	Training Loss: 0.662303
# Epoch: 36 	Training Loss: 0.661487
# Epoch: 37 	Training Loss: 0.662401
# Epoch: 38 	Training Loss: 0.661698
# Epoch: 39 	Training Loss: 0.661840
# Epoch: 40 	Training Loss: 0.662211
# Epoch: 41 	Training Loss: 0.661419
# Epoch: 42 	Training Loss: 0.662491
# Epoch: 43 	Training Loss: 0.661048
# Epoch: 44 	Training Loss: 0.661535
# Epoch: 45 	Training Loss: 0.661315
# Epoch: 46 	Training Loss: 0.659579
# Epoch: 47 	Training Loss: 0.660710
# Epoch: 48 	Training Loss: 0.660458
# Epoch: 49 	Training Loss: 0.661450
# Epoch: 50 	Training Loss: 0.659470
# Epoch: 51 	Training Loss: 0.659870
# Epoch: 52 	Training Loss: 0.659881
# Epoch: 53 	Training Loss: 0.660033
# Epoch: 54 	Training Loss: 0.659525
# Epoch: 55 	Training Loss: 0.659015
# Epoch: 56 	Training Loss: 0.658716
# Epoch: 57 	Training Loss: 0.659561
# Epoch: 58 	Training Loss: 0.659554
# Epoch: 59 	Training Loss: 0.660186
# Epoch: 60 	Training Loss: 0.659179
# Epoch: 61 	Training Loss: 0.658419
# Epoch: 62 	Training Loss: 0.659024
# Epoch: 63 	Training Loss: 0.658201
# Epoch: 64 	Training Loss: 0.658731
# Epoch: 65 	Training Loss: 0.658052
# Epoch: 66 	Training Loss: 0.659131
# Epoch: 67 	Training Loss: 0.658458
# Epoch: 68 	Training Loss: 0.657466
# Epoch: 69 	Training Loss: 0.658919
# Epoch: 70 	Training Loss: 0.657579
# Epoch: 71 	Training Loss: 0.657039
# Epoch: 72 	Training Loss: 0.657720
# Epoch: 73 	Training Loss: 0.657974
# Epoch: 74 	Training Loss: 0.657064
# Epoch: 75 	Training Loss: 0.655815
# Epoch: 76 	Training Loss: 0.656259
# Epoch: 77 	Training Loss: 0.655058
# Epoch: 78 	Training Loss: 0.657459
# Epoch: 79 	Training Loss: 0.655711
# Epoch: 80 	Training Loss: 0.656121
# Epoch: 81 	Training Loss: 0.657062
# Epoch: 82 	Training Loss: 0.655514
# Epoch: 83 	Training Loss: 0.657683
# Epoch: 84 	Training Loss: 0.655694
# Epoch: 85 	Training Loss: 0.656047
# Epoch: 86 	Training Loss: 0.654853
# Epoch: 87 	Training Loss: 0.654758
# Epoch: 88 	Training Loss: 0.656909
# Epoch: 89 	Training Loss: 0.655744
# Epoch: 90 	Training Loss: 0.654275
# Epoch: 91 	Training Loss: 0.654332
# Epoch: 92 	Training Loss: 0.653260
# Epoch: 93 	Training Loss: 0.655764
# Epoch: 94 	Training Loss: 0.652938
# Epoch: 95 	Training Loss: 0.653578
# Epoch: 96 	Training Loss: 0.653962
# Epoch: 97 	Training Loss: 0.654394
# Epoch: 98 	Training Loss: 0.654838
# Epoch: 99 	Training Loss: 0.654512
# Epoch: 100 	Training Loss: 0.654942
# Epoch: 101 	Training Loss: 0.651476
# Epoch: 102 	Training Loss: 0.654075
# Epoch: 103 	Training Loss: 0.654837
# Epoch: 104 	Training Loss: 0.653443
# Epoch: 105 	Training Loss: 0.652568
# Epoch: 106 	Training Loss: 0.653542
# Epoch: 107 	Training Loss: 0.654376
# Epoch: 108 	Training Loss: 0.653194
# Epoch: 109 	Training Loss: 0.653120
# Epoch: 110 	Training Loss: 0.651922
# Epoch: 111 	Training Loss: 0.653328
# Epoch: 112 	Training Loss: 0.652421
# Epoch: 113 	Training Loss: 0.651115
# Epoch: 114 	Training Loss: 0.651509
# Epoch: 115 	Training Loss: 0.651080
# Epoch: 116 	Training Loss: 0.651886
# Epoch: 117 	Training Loss: 0.656262
# Epoch: 118 	Training Loss: 0.656161
# Epoch: 119 	Training Loss: 0.652656
# Epoch: 120 	Training Loss: 0.654711
# Epoch: 121 	Training Loss: 0.652774
# Epoch: 122 	Training Loss: 0.653252
# Epoch: 123 	Training Loss: 0.652719
# Epoch: 124 	Training Loss: 0.651369
# Epoch: 125 	Training Loss: 0.652059
# Epoch: 126 	Training Loss: 0.649305
# Epoch: 127 	Training Loss: 0.650110
# Epoch: 128 	Training Loss: 0.648821
# Epoch: 129 	Training Loss: 0.649610
# Epoch: 130 	Training Loss: 0.651248
# Epoch: 131 	Training Loss: 0.651506
# Epoch: 132 	Training Loss: 0.650307
# Epoch: 133 	Training Loss: 0.648986
# Epoch: 134 	Training Loss: 0.649595
# Epoch: 135 	Training Loss: 0.648630
# Epoch: 136 	Training Loss: 0.647935
# Epoch: 137 	Training Loss: 0.648873
# Epoch: 138 	Training Loss: 0.650733
# Epoch: 139 	Training Loss: 0.649271
# Epoch: 140 	Training Loss: 0.647921
# Epoch: 141 	Training Loss: 0.649788
# Epoch: 142 	Training Loss: 0.647931
# Epoch: 143 	Training Loss: 0.649902
# Epoch: 144 	Training Loss: 0.647767
# Epoch: 145 	Training Loss: 0.648085
# Epoch: 146 	Training Loss: 0.648559
# Epoch: 147 	Training Loss: 0.649964
# Epoch: 148 	Training Loss: 0.651347
# Epoch: 149 	Training Loss: 0.645383
# Epoch: 150 	Training Loss: 0.646526
# Epoch: 151 	Training Loss: 0.645414
# Epoch: 152 	Training Loss: 0.647286
# Epoch: 153 	Training Loss: 0.645487
# Epoch: 154 	Training Loss: 0.645686
# Epoch: 155 	Training Loss: 0.646117
# Epoch: 156 	Training Loss: 0.645081
# Epoch: 157 	Training Loss: 0.646698
# Epoch: 158 	Training Loss: 0.645409
# Epoch: 159 	Training Loss: 0.647818
# Epoch: 160 	Training Loss: 0.646364
# Epoch: 161 	Training Loss: 0.646171
# Epoch: 162 	Training Loss: 0.646737
# Epoch: 163 	Training Loss: 0.644687
# Epoch: 164 	Training Loss: 0.647751
# Epoch: 165 	Training Loss: 0.645557
# Epoch: 166 	Training Loss: 0.644728
# Epoch: 167 	Training Loss: 0.645317
# Epoch: 168 	Training Loss: 0.644802
# Epoch: 169 	Training Loss: 0.645401
# Epoch: 170 	Training Loss: 0.642424
# Epoch: 171 	Training Loss: 0.646070
# Epoch: 172 	Training Loss: 0.645594
# Epoch: 173 	Training Loss: 0.643233
# Epoch: 174 	Training Loss: 0.645739
# Epoch: 175 	Training Loss: 0.644100
# Epoch: 176 	Training Loss: 0.642330
# Epoch: 177 	Training Loss: 0.644733
# Epoch: 178 	Training Loss: 0.645256
# Epoch: 179 	Training Loss: 0.643141
# Epoch: 180 	Training Loss: 0.643990
# Epoch: 181 	Training Loss: 0.643987
# Epoch: 182 	Training Loss: 0.643655
# Epoch: 183 	Training Loss: 0.645009
# Epoch: 184 	Training Loss: 0.642894
# Epoch: 185 	Training Loss: 0.642610
# Epoch: 186 	Training Loss: 0.643458
# Epoch: 187 	Training Loss: 0.642924
# Epoch: 188 	Training Loss: 0.642295
# Epoch: 189 	Training Loss: 0.642964
# Epoch: 190 	Training Loss: 0.641386
# Epoch: 191 	Training Loss: 0.640681
# Epoch: 192 	Training Loss: 0.643263
# Epoch: 193 	Training Loss: 0.642822
# Epoch: 194 	Training Loss: 0.644431
# Epoch: 195 	Training Loss: 0.641176
# Epoch: 196 	Training Loss: 0.641240
# Epoch: 197 	Training Loss: 0.640585
# Epoch: 198 	Training Loss: 0.641947
# Epoch: 199 	Training Loss: 0.640219
# Train Loss:	 0.64022 , 	Test Loss:	 0.66562
# Train Accuracy:	 0.50875 , 	Test Accuracy:	 0.50587
# Precision:	 41.58065 , 	Recall:	 44.35484

# %%
epochs = 200
results = train_net(train_loader,dev_loader,lr_rate)
# Out:
# Epoch: 0 	Training Loss: 0.639898
# Epoch: 1 	Training Loss: 0.643247
# Epoch: 2 	Training Loss: 0.639280
# Epoch: 3 	Training Loss: 0.638614
# Epoch: 4 	Training Loss: 0.639054
# Epoch: 5 	Training Loss: 0.640637
# Epoch: 6 	Training Loss: 0.637410
# Epoch: 7 	Training Loss: 0.638300
# Epoch: 8 	Training Loss: 0.636735
# Epoch: 9 	Training Loss: 0.639243
# Epoch: 10 	Training Loss: 0.637875
# Epoch: 11 	Training Loss: 0.637920
# Epoch: 12 	Training Loss: 0.638642
# Epoch: 13 	Training Loss: 0.640193
# Epoch: 14 	Training Loss: 0.639678
# Epoch: 15 	Training Loss: 0.636920
# Epoch: 16 	Training Loss: 0.635626
# Epoch: 17 	Training Loss: 0.640190
# Epoch: 18 	Training Loss: 0.639754
# Epoch: 19 	Training Loss: 0.638576
# Epoch: 20 	Training Loss: 0.639486
# Epoch: 21 	Training Loss: 0.637925
# Epoch: 22 	Training Loss: 0.638306
# Epoch: 23 	Training Loss: 0.636530
# Epoch: 24 	Training Loss: 0.638186
# Epoch: 25 	Training Loss: 0.638432
# Epoch: 26 	Training Loss: 0.642226
# Epoch: 27 	Training Loss: 0.639554
# Epoch: 28 	Training Loss: 0.636836
# Epoch: 29 	Training Loss: 0.636897
# Epoch: 30 	Training Loss: 0.637761
# Epoch: 31 	Training Loss: 0.635844
# Epoch: 32 	Training Loss: 0.636353
# Epoch: 33 	Training Loss: 0.636762
# Epoch: 34 	Training Loss: 0.639248
# Epoch: 35 	Training Loss: 0.635316
# Epoch: 36 	Training Loss: 0.638809
# Epoch: 37 	Training Loss: 0.636857
# Epoch: 38 	Training Loss: 0.640396
# Epoch: 39 	Training Loss: 0.637478
# Epoch: 40 	Training Loss: 0.635849
# Epoch: 41 	Training Loss: 0.634639
# Epoch: 42 	Training Loss: 0.637121
# Epoch: 43 	Training Loss: 0.636910
# Epoch: 44 	Training Loss: 0.635153
# Epoch: 45 	Training Loss: 0.635295
# Epoch: 46 	Training Loss: 0.636323
# Epoch: 47 	Training Loss: 0.636037
# Epoch: 48 	Training Loss: 0.635736
# Epoch: 49 	Training Loss: 0.634940
# Epoch: 50 	Training Loss: 0.636783
# Epoch: 51 	Training Loss: 0.636525
# Epoch: 52 	Training Loss: 0.636620
# Epoch: 53 	Training Loss: 0.637280
# Epoch: 54 	Training Loss: 0.633359
# Epoch: 55 	Training Loss: 0.638513
# Epoch: 56 	Training Loss: 0.636346
# Epoch: 57 	Training Loss: 0.638400
# Epoch: 58 	Training Loss: 0.635365
# Epoch: 59 	Training Loss: 0.637236
# Epoch: 60 	Training Loss: 0.635453
# Epoch: 61 	Training Loss: 0.635014
# Epoch: 62 	Training Loss: 0.637487
# Epoch: 63 	Training Loss: 0.638553
# Epoch: 64 	Training Loss: 0.637250
# Epoch: 65 	Training Loss: 0.636459
# Epoch: 66 	Training Loss: 0.636362
# Epoch: 67 	Training Loss: 0.635388
# Epoch: 68 	Training Loss: 0.633717
# Epoch: 69 	Training Loss: 0.631332
# Epoch: 70 	Training Loss: 0.634351
# Epoch: 71 	Training Loss: 0.634324
# Epoch: 72 	Training Loss: 0.636640
# Epoch: 73 	Training Loss: 0.631280
# Epoch: 74 	Training Loss: 0.634352
# Epoch: 75 	Training Loss: 0.632126
# Epoch: 76 	Training Loss: 0.632880
# Epoch: 77 	Training Loss: 0.631541
# Epoch: 78 	Training Loss: 0.635477
# Epoch: 79 	Training Loss: 0.633109
# Epoch: 80 	Training Loss: 0.635754
# Epoch: 81 	Training Loss: 0.636589
# Epoch: 82 	Training Loss: 0.634264
# Epoch: 83 	Training Loss: 0.633558
# Epoch: 84 	Training Loss: 0.635886
# Epoch: 85 	Training Loss: 0.634916
# Epoch: 86 	Training Loss: 0.633725
# Epoch: 87 	Training Loss: 0.637174
# Epoch: 88 	Training Loss: 0.634456
# Epoch: 89 	Training Loss: 0.634350
# Epoch: 90 	Training Loss: 0.632535
# Epoch: 91 	Training Loss: 0.634292
# Epoch: 92 	Training Loss: 0.631840
# Epoch: 93 	Training Loss: 0.635640
# Epoch: 94 	Training Loss: 0.629856
# Epoch: 95 	Training Loss: 0.634567
# Epoch: 96 	Training Loss: 0.633470
# Epoch: 97 	Training Loss: 0.632289
# Epoch: 98 	Training Loss: 0.632449
# Epoch: 99 	Training Loss: 0.632072
# Epoch: 100 	Training Loss: 0.634563
# Epoch: 101 	Training Loss: 0.633382
# Epoch: 102 	Training Loss: 0.631082
# Epoch: 103 	Training Loss: 0.630316
# Epoch: 104 	Training Loss: 0.633856
# Epoch: 105 	Training Loss: 0.632906
# Epoch: 106 	Training Loss: 0.632899
# Epoch: 107 	Training Loss: 0.631523
# Epoch: 108 	Training Loss: 0.630925
# Epoch: 109 	Training Loss: 0.631656
# Epoch: 110 	Training Loss: 0.633389
# Epoch: 111 	Training Loss: 0.631604
# Epoch: 112 	Training Loss: 0.633699
# Epoch: 113 	Training Loss: 0.633447
# Epoch: 114 	Training Loss: 0.634220
# Epoch: 115 	Training Loss: 0.632476
# Epoch: 116 	Training Loss: 0.631730
# Epoch: 117 	Training Loss: 0.630906
# Epoch: 118 	Training Loss: 0.636345
# Epoch: 119 	Training Loss: 0.630660
# Epoch: 120 	Training Loss: 0.632284
# Epoch: 121 	Training Loss: 0.630248
# Epoch: 122 	Training Loss: 0.633210
# Epoch: 123 	Training Loss: 0.628897
# Epoch: 124 	Training Loss: 0.631801
# Epoch: 125 	Training Loss: 0.635120
# Epoch: 126 	Training Loss: 0.632561
# Epoch: 127 	Training Loss: 0.633614
# Epoch: 128 	Training Loss: 0.632369
# Epoch: 129 	Training Loss: 0.629781
# Epoch: 130 	Training Loss: 0.632806
# Epoch: 131 	Training Loss: 0.634546
# Epoch: 132 	Training Loss: 0.634923
# Epoch: 133 	Training Loss: 0.633617
# Epoch: 134 	Training Loss: 0.632581
# Epoch: 135 	Training Loss: 0.632198
# Epoch: 136 	Training Loss: 0.631543
# Epoch: 137 	Training Loss: 0.631068
# Epoch: 138 	Training Loss: 0.631578
# Epoch: 139 	Training Loss: 0.630366
# Epoch: 140 	Training Loss: 0.632894
# Epoch: 141 	Training Loss: 0.630873
# Epoch: 142 	Training Loss: 0.632427
# Epoch: 143 	Training Loss: 0.630272
# Epoch: 144 	Training Loss: 0.631749
# Epoch: 145 	Training Loss: 0.628941
# Epoch: 146 	Training Loss: 0.631630
# Epoch: 147 	Training Loss: 0.637352
# Epoch: 148 	Training Loss: 0.632306
# Epoch: 149 	Training Loss: 0.631694
# Epoch: 150 	Training Loss: 0.630486
# Epoch: 151 	Training Loss: 0.629817
# Epoch: 152 	Training Loss: 0.631392
# Epoch: 153 	Training Loss: 0.628746
# Epoch: 154 	Training Loss: 0.633079
# Epoch: 155 	Training Loss: 0.629475
# Epoch: 156 	Training Loss: 0.629898
# Epoch: 157 	Training Loss: 0.631493
# Epoch: 158 	Training Loss: 0.633012
# Epoch: 159 	Training Loss: 0.629922
# Epoch: 160 	Training Loss: 0.630584
# Epoch: 161 	Training Loss: 0.631888
# Epoch: 162 	Training Loss: 0.629289
# Epoch: 163 	Training Loss: 0.630014
# Epoch: 164 	Training Loss: 0.627930
# Epoch: 165 	Training Loss: 0.630752
# Epoch: 166 	Training Loss: 0.629300
# Epoch: 167 	Training Loss: 0.627990
# Epoch: 168 	Training Loss: 0.632130
# Epoch: 169 	Training Loss: 0.630223
# Epoch: 170 	Training Loss: 0.627649
# Epoch: 171 	Training Loss: 0.628001
# Epoch: 172 	Training Loss: 0.629645
# Epoch: 173 	Training Loss: 0.628645
# Epoch: 174 	Training Loss: 0.627717
# Epoch: 175 	Training Loss: 0.628531
# Epoch: 176 	Training Loss: 0.628877
# Epoch: 177 	Training Loss: 0.628075
# Epoch: 178 	Training Loss: 0.629496
# Epoch: 179 	Training Loss: 0.627657
# Epoch: 180 	Training Loss: 0.627649
# Epoch: 181 	Training Loss: 0.630612
# Epoch: 182 	Training Loss: 0.628632
# Epoch: 183 	Training Loss: 0.629834
# Epoch: 184 	Training Loss: 0.630133
# Epoch: 185 	Training Loss: 0.628792
# Epoch: 186 	Training Loss: 0.629077
# Epoch: 187 	Training Loss: 0.630377
# Epoch: 188 	Training Loss: 0.628960
# Epoch: 189 	Training Loss: 0.625898
# Epoch: 190 	Training Loss: 0.626641
# Epoch: 191 	Training Loss: 0.628546
# Epoch: 192 	Training Loss: 0.627812
# Epoch: 193 	Training Loss: 0.625036
# Epoch: 194 	Training Loss: 0.626869
# Epoch: 195 	Training Loss: 0.627763
# Epoch: 196 	Training Loss: 0.628187
# Epoch: 197 	Training Loss: 0.628894
# Epoch: 198 	Training Loss: 0.629570
# Epoch: 199 	Training Loss: 0.629155
# Train Loss:	 0.62915 , 	Test Loss:	 0.66995
# Train Accuracy:	 0.65166 , 	Test Accuracy:	 0.6357
# Precision:	 0.67342 , 	Recall:	 0.59462

# %%
420
Train Loss:	 0.62915 , 	Test Loss:	 0.66995
Train Accuracy:	 0.65166 , 	Test Accuracy:	 0.6357
Precision:	 0.67342 , 	Recall:	 0.59462

# %%
## save model
outfile = open("model_1024.pkl",'wb')
pickle.dump(last_model, outfile)
outfile.close()

# %%
last_model = model

# %%
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-109-976cbd5fe599> in <module>
#       1 ## save model
#       2 outfile = open("model_1024.pkl",'wb')
# ----> 3 pickle.dump(last_model, outfile)
#       4 outfile.close()
#
# PicklingError: Can't pickle <class '__main__.Net'>: it's not the same object as __main__.Net

# %%
## model_1 is the best model
loadfile = open("model_1.pkl",'rb')
saved_model = pickle.load(loadfile)
loadfile.close()
test_net(dev_loader, saved_model, torch.nn.BCELoss())
# Out:
# (0.013583977685072031, 0.9649573037790697, 0.9985232543254862, 1.0)

# %%
loadfile = open("model_init.pkl",'rb')
model_init = pickle.load(loadfile)
loadfile.close()

# %%
import copy
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10)
batch_size = 64
cv_results = {}

for fold, (train_index, test_index) in enumerate(kfold.split(x, y)):
    x_train_fold = x[train_index]
    x_test_fold = x[test_index]
    y_train_fold = y[train_index]
    y_test_fold = y[test_index]
    
    train_loader = torch.utils.data.DataLoader(dataset=tuple(zip(x_train_fold,y_train_fold)), batch_size = batch_size, shuffle = True)
    test_loader = torch.utils.data.DataLoader(dataset=tuple(zip(x_test_fold,y_test_fold)), batch_size = batch_size, shuffle = False)
    
    model.load_state_dict(init_state)
    optimizer.load_state_dict(init_state_opt)
    model.to(device)
    
    cv_results[fold] = train_net(train_loader,dev_loader,lr_rate)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/huangraelene/opt/anaconda3/envs/tnsfl/lib/python3.7/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([3])) that is different to the input size (torch.Size([3, 1])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# 100%|██████████| 10/10 [00:53<00:00,  5.37s/it]
# Train Loss:  0.013925376385699998 , Test Loss:  0.013601134293694578
# Train Accuracy:  0.9612101765422078 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
# 100%|██████████| 10/10 [00:55<00:00,  5.58s/it]
# Train Loss:  0.013784325032620066 , Test Loss:  0.014498367940299187
# Train Accuracy:  0.961520900974026 , Test Accuracy:  0.9627997819767442
# Precision:  0.9992732558139535 , Recall:  1.0
# 100%|██████████| 10/10 [01:02<00:00,  6.28s/it]
# Train Loss:  0.013643661441529027 , Test Loss:  0.013601053983546517
# Train Accuracy:  0.9619457690746753 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
# 100%|██████████| 10/10 [00:56<00:00,  5.66s/it]
# Train Loss:  0.014065557252627793 , Test Loss:  0.014249967757855886
# Train Accuracy:  0.9609628652597403 , Test Accuracy:  0.962425054505814
# Precision:  0.9996249062265566 , Recall:  1.0
# 100%|██████████| 10/10 [00:55<00:00,  5.51s/it]
# Train Loss:  0.013222004240870553 , Test Loss:  0.014368281549503849
# Train Accuracy:  0.9634359780844156 , Test Accuracy:  0.9624477652616279
# Precision:  0.9996366279069767 , Recall:  1.0
# 100%|██████████| 10/10 [01:01<00:00,  6.19s/it]
# Train Loss:  0.01420654689110242 , Test Loss:  0.013601260678878818
# Train Accuracy:  0.9604999492694806 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
# 100%|██████████| 10/10 [00:58<00:00,  5.83s/it]
# Train Loss:  0.014347694744022834 , Test Loss:  0.01360138194422887
# Train Accuracy:  0.9599736201298701 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
# 100%|██████████| 10/10 [00:58<00:00,  5.83s/it]
# Train Loss:  0.013362392565465094 , Test Loss:  0.013601053896962392
# Train Accuracy:  0.9627194094967533 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/huangraelene/opt/anaconda3/envs/tnsfl/lib/python3.7/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([4])) that is different to the input size (torch.Size([4, 1])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# 100%|██████████| 10/10 [00:57<00:00,  5.75s/it]
# Train Loss:  0.01378476469192368 , Test Loss:  0.014431673950200908
# Train Accuracy:  0.961711140422078 , Test Accuracy:  0.962425054505814
# Precision:  0.9996249062265566 , Recall:  1.0
# 100%|██████████| 10/10 [00:51<00:00,  5.16s/it]
# Train Loss:  0.013643774487471012 , Test Loss:  0.01360114166206253
# Train Accuracy:  0.9619711343344156 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0

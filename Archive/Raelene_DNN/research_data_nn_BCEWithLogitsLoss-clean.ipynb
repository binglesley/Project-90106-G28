# %%
#from google.colab import files
#uploaded = files.upload()

# %%
import numpy as np
import pandas as pd
from tqdm import tqdm
from matplotlib import style
import matplotlib.pyplot as plt
import random
import torch
from torch.autograd import Variable
import torch.nn.functional as F
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
import pickle
import copy
style.use("ggplot")

def plot(train_rolling_loss,dev_rolling_loss,train_rolling_acc,dev_rolling_acc):
    plt.figure(figsize=(15,10))
    plt.subplot(221)
    plt.plot(train_rolling_loss,label="training")
    plt.plot(dev_rolling_loss,label="dev")
    plt.title("Rolling Loss",loc='center')
    plt.legend(loc=1)
    plt.subplot(222)
    plt.plot(train_rolling_acc,label="training")
    plt.plot(dev_rolling_acc,label="dev")
    plt.title("Rolling Accuracy",loc='center')
    plt.legend(loc=0)
    plt.show()

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
torch.cuda.device_count()
torch.cuda.is_available()
# Out:
# False

# %% [markdown]
# # 1. Pre-process dataset

# %%
## reading clean data
raw = pd.read_csv('cleaned-16-Oct.csv')
raw = raw.drop(['oppo_busi','fac_oppo', 'oppo_Industry'],axis=1)
raw.describe()
# Out:
#          StageName  Parent_Opportunity__c  Is_External__c     ParentId  \
# count  5408.000000            5408.000000     5408.000000  5408.000000
# mean      0.373706               0.098743        0.992604     0.162722
# std       0.483832               0.298344        0.085692     0.369146
# min       0.000000               0.000000        0.000000     0.000000
# 25%       0.000000               0.000000        1.000000     0.000000
# 50%       0.000000               0.000000        1.000000     0.000000
# 75%       1.000000               0.000000        1.000000     0.000000
# max       1.000000               1.000000        1.000000     1.000000
#
#        tasks_events  CreatedYear  CreatedMonth          days          RN  \
# count   5408.000000  5408.000000    5408.00000   5408.000000  5408.00000
# mean       0.063609  2017.855954       6.32304    470.180288    23.11372
# std        0.244079     1.308152       3.19268    519.571149    49.01797
# min        0.000000  2015.000000       1.00000   -426.000000     1.00000
# 25%        0.000000  2017.000000       4.00000     87.000000     1.00000
# 50%        0.000000  2018.000000       6.00000    333.000000     2.00000
# 75%        0.000000  2019.000000       9.00000    826.000000    15.00000
# max        1.000000  2020.000000      12.00000  11618.000000   279.00000
#
#        f_won_before
# count   5408.000000
# mean       0.457101
# std        0.498202
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000

# %%
raw["StageName"].value_counts(dropna=False)
# Out:
# 0    3387
# 1    2021
# Name: StageName, dtype: int64

# %%
data = pd.concat([raw, raw[raw["StageName"]==1]], axis=0, ignore_index=True)
data["StageName"].value_counts(dropna=False).plot(kind="barh")
from sklearn.utils import shuffle
data = shuffle(data)

# %% [markdown]
# ## 1.2 One-Hot-Encoding

# %%
## one-hot-encoding

a = pd.get_dummies(data["RecordType.Name"], prefix='RecordType')
b = pd.get_dummies(data["RICE_Supported__c"], prefix='RICE_Supported')
c = pd.get_dummies(data["Lead_Faculty__c"], prefix='Lead_Faculty')
d = pd.get_dummies(data["Lead_School__c"], prefix='Lead_School')
e = pd.get_dummies(data["Industry"], prefix='Industry')
f = pd.get_dummies(data["Industry_Sub_Type__c"], prefix='Industry_Sub')
g = pd.get_dummies(data["Business_Type__c"], prefix='Business')

org = data[["StageName","Parent_Opportunity__c","Is_External__c","ParentId","f_won_before"]]

scale3 = data["CreatedYear"].div(2020)
scale4 = data["CreatedMonth"].div(12)
scale5 = data["days"].div(11618)
scale6 = data["RN"].div(279)

#df = pd.concat([org,scale3,scale4,scale5,scale6,a,b,c,d,e,f,g], axis=1, ignore_index=True)
df = pd.concat([org,scale3,scale4,scale5,scale6], axis=1, ignore_index=True)
df
# Out:
#       0  1  2  3  4         5         6         7         8
# 3998  1  0  1  0  1  0.998515  1.000000  0.058702  0.039427
# 5794  1  0  1  0  0  0.998515  0.666667  0.068773  0.003584
# 98    0  0  1  0  0  0.999010  0.583333  0.003873  0.003584
# 2743  0  0  1  0  0  0.999505  0.833333  0.000861  0.003584
# 2320  0  0  1  1  1  0.999505  0.250000  0.004390  0.046595
# ...  .. .. .. .. ..       ...       ...       ...       ...
# 5817  1  0  1  0  0  0.998020  0.416667  0.108194  0.003584
# 1496  0  0  1  0  0  0.999505  0.416667  0.020658  0.003584
# 2802  0  0  1  0  0  0.999010  0.250000  0.050697  0.003584
# 6508  1  1  1  0  1  0.999505  0.666667  0.014288  0.007168
# 673   0  0  1  0  0  0.997525  0.833333  0.126872  0.003584
#
# [7429 rows x 9 columns]

# %%
# split xy
x = torch.Tensor([i[1:] for i in df.values.tolist()])
y = torch.Tensor([i[0] for i in df.values.tolist()])

# train/dev split
batch_size = 64+16
x_train, x_dev, y_train, y_dev = train_test_split(x, y, test_size=0.33, random_state=42)
train_loader = torch.utils.data.DataLoader(dataset=tuple(zip(x_train,y_train)), batch_size=batch_size, shuffle=True)
dev_loader = torch.utils.data.DataLoader(dataset=tuple(zip(x_dev,y_dev)), batch_size=batch_size, shuffle=True)

# %%
n_features, n_classes = int(x_train.shape[1]), 1

# %% [markdown]
# # 2. Neural Network Model

# %%
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import accuracy_score

class Net(torch.nn.Module):

    def __init__(self):
        super(Net, self).__init__()
        self.linear1 = torch.nn.Linear(n_features,1024)
        self.linear2 = torch.nn.Linear(1024, 1024)
        self.linear3 = torch.nn.Linear(1024, 1024)
        self.linear4 = torch.nn.Linear(1024, 1024)
        self.linear5 = torch.nn.Linear(1024, 1024)
        self.linear6 = torch.nn.Linear(1024, 1024)
        self.linear7 = torch.nn.Linear(1024, n_classes)

    def forward(self, x):
        x = F.relu(self.linear1(x))
        x = F.relu(self.linear2(x))
        x = F.relu(self.linear3(x))
        x = F.relu(self.linear4(x))
        x = F.relu(self.linear5(x))
        x = F.relu(self.linear6(x))
        x = F.relu(self.linear7(x))
        return x
    
def eval_metrics(raw_output,labels):
    outputs = torch.round(torch.sigmoid(raw_output)).detach()
    
    target_true = torch.sum(labels == 1).float()
    predicted_true = torch.sum(outputs).float()
    correct_true = torch.sum(labels * outputs).float()
    
    accuracy = torch.mean(torch.eq(outputs, labels).float()).item()
    precision = correct_true / (predicted_true)
    recall = correct_true / target_true
    
    return accuracy, precision.cpu().item(), recall.cpu().item()


def eval_metrics(raw_output,labels):
    outputs = torch.round(torch.sigmoid(raw_output)).detach()
    accuracy = accuracy_score(labels.detach().numpy(), outputs.numpy())
    precision = precision_score(labels.detach().numpy(), outputs.numpy())
    recall = recall_score(labels.detach().numpy(), outputs.numpy())
    return accuracy, precision, recall


def test_net(test_loader):
    test_loss,test_acc,test_prec,test_rec = 0.,0.,0.,0.
    scale = len(test_loader)
    
    for features, labels in test_loader:
        features = Variable(features).to(device)
        labels = Variable(labels).to(device)
        outputs = model(features)
        loss = criterion(outputs, labels.unsqueeze(1))
        test_loss += loss.item()

        a,b,c = eval_metrics(outputs,labels)
        test_acc += a
        test_prec += b
        test_rec += c
        
    return test_acc/scale, test_prec/scale, test_rec/scale, test_loss/scale


def train_net(train_loader,dev_loader,lr_rate):
    train_rolling_loss,dev_rolling_loss,train_rolling_acc,dev_rolling_acc = [],[],[],[]
    test_precision,test_recall = [],[]

    for epoch in range(int(epochs)):
        train_loss,train_acc = 0.,0.
        
        for i, (features, labels) in enumerate(train_loader):
            features = Variable(features).to(device)
            labels = Variable(labels).to(device)
            optimizer.zero_grad()
            outputs = model(features)
            loss = criterion(outputs, labels.unsqueeze(1))
            
            train_loss += loss.item()
            acc,_,_ = eval_metrics(outputs,labels)
            train_acc += acc
            
            loss.backward()
            optimizer.step()
            
        
        train_rolling_acc.append(train_acc/len(train_loader))
        train_rolling_loss.append(train_loss/len(train_loader))

        ## Development Dataset
        dev_acc,precision,recall,dev_loss = test_net(dev_loader)
        dev_rolling_acc.append(dev_acc)
        test_precision.append(precision)
        test_recall.append(recall)
        dev_rolling_loss.append(dev_loss)
        
        print('Epoch: {} \tTraining Loss: {:.6f}'.format(epoch, train_loss/len(train_loader)))
        
    print("Train Loss:\t",round(train_rolling_loss[-1],5),", \tTest Loss:\t",round(dev_rolling_loss[-1],5))
    print("Train Accuracy:\t",round(train_rolling_acc[-1],5),", \tTest Accuracy:\t",round(dev_rolling_acc[-1],5))
    print("Precision:\t",round(test_precision[-1],5),", \tRecall:\t",round(test_recall[-1],5))
    
    plot(train_rolling_loss,dev_rolling_loss,train_rolling_acc,dev_rolling_acc)
    
    plt.figure(figsize=(15,10))
    plt.subplot(221)
    plt.plot(test_precision,label="training")
    plt.subplot(222)
    plt.plot(test_recall,label="training")
    plt.show()
    
    return dev_rolling_loss,dev_rolling_acc,test_precision,test_recall

# %%
model = Net()
init_state = copy.deepcopy(model.state_dict())
criterion = torch.nn.BCEWithLogitsLoss() # BCELoss

# %%
epochs = 10
lr_rate = 0.001
optimizer = torch.optim.Adam(model.parameters(), lr=lr_rate)
init_state_opt = copy.deepcopy(optimizer.state_dict())

# %%
#### RUN MODEL
epochs = 500
model.load_state_dict(init_state)
optimizer.load_state_dict(init_state_opt)
model.to(device)
results = train_net(train_loader,dev_loader,lr_rate)
# Out:
# Epoch: 0 	Training Loss: 0.683445
# Epoch: 1 	Training Loss: 0.672485
# Epoch: 2 	Training Loss: 0.672925
# Epoch: 3 	Training Loss: 0.671223
# Epoch: 4 	Training Loss: 0.670794
# Epoch: 5 	Training Loss: 0.668775
# Epoch: 6 	Training Loss: 0.674211
# Epoch: 7 	Training Loss: 0.671465
# Epoch: 8 	Training Loss: 0.673240
# Epoch: 9 	Training Loss: 0.669718
# Epoch: 10 	Training Loss: 0.668516
# Epoch: 11 	Training Loss: 0.669865
# Epoch: 12 	Training Loss: 0.667206
# Epoch: 13 	Training Loss: 0.666079
# Epoch: 14 	Training Loss: 0.666656
# Epoch: 15 	Training Loss: 0.667650
# Epoch: 16 	Training Loss: 0.668732
# Epoch: 17 	Training Loss: 0.668037
# Epoch: 18 	Training Loss: 0.666700
# Epoch: 19 	Training Loss: 0.669046
# Epoch: 20 	Training Loss: 0.667368
# Epoch: 21 	Training Loss: 0.667473
# Epoch: 22 	Training Loss: 0.665483
# Epoch: 23 	Training Loss: 0.665997
# Epoch: 24 	Training Loss: 0.665403
# Epoch: 25 	Training Loss: 0.671248
# Epoch: 26 	Training Loss: 0.669607
# Epoch: 27 	Training Loss: 0.666646
# Epoch: 28 	Training Loss: 0.667859
# Epoch: 29 	Training Loss: 0.667412
# Epoch: 30 	Training Loss: 0.664678
# Epoch: 31 	Training Loss: 0.663601
# Epoch: 32 	Training Loss: 0.666547
# Epoch: 33 	Training Loss: 0.664963
# Epoch: 34 	Training Loss: 0.663176
# Epoch: 35 	Training Loss: 0.661109
# Epoch: 36 	Training Loss: 0.661051
# Epoch: 37 	Training Loss: 0.663825
# Epoch: 38 	Training Loss: 0.664504
# Epoch: 39 	Training Loss: 0.662444
# Epoch: 40 	Training Loss: 0.659472
# Epoch: 41 	Training Loss: 0.662859
# Epoch: 42 	Training Loss: 0.663281
# Epoch: 43 	Training Loss: 0.663057
# Epoch: 44 	Training Loss: 0.660540
# Epoch: 45 	Training Loss: 0.661451
# Epoch: 46 	Training Loss: 0.660919
# Epoch: 47 	Training Loss: 0.661266
# Epoch: 48 	Training Loss: 0.660933
# Epoch: 49 	Training Loss: 0.661503
# Epoch: 50 	Training Loss: 0.661416
# Epoch: 51 	Training Loss: 0.659634
# Epoch: 52 	Training Loss: 0.661877
# Epoch: 53 	Training Loss: 0.662711
# Epoch: 54 	Training Loss: 0.656970
# Epoch: 55 	Training Loss: 0.659917
# Epoch: 56 	Training Loss: 0.657385
# Epoch: 57 	Training Loss: 0.659479
# Epoch: 58 	Training Loss: 0.659505
# Epoch: 59 	Training Loss: 0.658811
# Epoch: 60 	Training Loss: 0.657915
# Epoch: 61 	Training Loss: 0.658716
# Epoch: 62 	Training Loss: 0.658380
# Epoch: 63 	Training Loss: 0.657464
# Epoch: 64 	Training Loss: 0.660122
# Epoch: 65 	Training Loss: 0.658722
# Epoch: 66 	Training Loss: 0.659074
# Epoch: 67 	Training Loss: 0.658764
# Epoch: 68 	Training Loss: 0.655722
# Epoch: 69 	Training Loss: 0.655289
# Epoch: 70 	Training Loss: 0.657407
# Epoch: 71 	Training Loss: 0.660467
# Epoch: 72 	Training Loss: 0.661618
# Epoch: 73 	Training Loss: 0.673997
# Epoch: 74 	Training Loss: 0.666191
# Epoch: 75 	Training Loss: 0.666822
# Epoch: 76 	Training Loss: 0.665233
# Epoch: 77 	Training Loss: 0.663136
# Epoch: 78 	Training Loss: 0.665241
# Epoch: 79 	Training Loss: 0.665033
# Epoch: 80 	Training Loss: 0.661466
# Epoch: 81 	Training Loss: 0.659846
# Epoch: 82 	Training Loss: 0.658333
# Epoch: 83 	Training Loss: 0.658194
# Epoch: 84 	Training Loss: 0.658769
# Epoch: 85 	Training Loss: 0.658773
# Epoch: 86 	Training Loss: 0.660129
# Epoch: 87 	Training Loss: 0.658479
# Epoch: 88 	Training Loss: 0.657916
# Epoch: 89 	Training Loss: 0.657606
# Epoch: 90 	Training Loss: 0.657996
# Epoch: 91 	Training Loss: 0.656802
# Epoch: 92 	Training Loss: 0.655319
# Epoch: 93 	Training Loss: 0.655568
# Epoch: 94 	Training Loss: 0.657606
# Epoch: 95 	Training Loss: 0.655849
# Epoch: 96 	Training Loss: 0.653321
# Epoch: 97 	Training Loss: 0.653618
# Epoch: 98 	Training Loss: 0.652117
# Epoch: 99 	Training Loss: 0.652934
# Epoch: 100 	Training Loss: 0.654793
# Epoch: 101 	Training Loss: 0.652581
# Epoch: 102 	Training Loss: 0.650492
# Epoch: 103 	Training Loss: 0.650233
# Epoch: 104 	Training Loss: 0.648008
# Epoch: 105 	Training Loss: 0.650060
# Epoch: 106 	Training Loss: 0.648767
# Epoch: 107 	Training Loss: 0.647979
# Epoch: 108 	Training Loss: 0.648705
# Epoch: 109 	Training Loss: 0.649529
# Epoch: 110 	Training Loss: 0.647949
# Epoch: 111 	Training Loss: 0.650027
# Epoch: 112 	Training Loss: 0.646619
# Epoch: 113 	Training Loss: 0.645285
# Epoch: 114 	Training Loss: 0.647030
# Epoch: 115 	Training Loss: 0.646994
# Epoch: 116 	Training Loss: 0.645483
# Epoch: 117 	Training Loss: 0.645820
# Epoch: 118 	Training Loss: 0.645286
# Epoch: 119 	Training Loss: 0.644866
# Epoch: 120 	Training Loss: 0.642389
# Epoch: 121 	Training Loss: 0.644493
# Epoch: 122 	Training Loss: 0.646860
# Epoch: 123 	Training Loss: 0.644829
# Epoch: 124 	Training Loss: 0.643559
# Epoch: 125 	Training Loss: 0.642979
# Epoch: 126 	Training Loss: 0.645625
# Epoch: 127 	Training Loss: 0.645915
# Epoch: 128 	Training Loss: 0.645423
# Epoch: 129 	Training Loss: 0.643962
# Epoch: 130 	Training Loss: 0.645484
# Epoch: 131 	Training Loss: 0.641273
# Epoch: 132 	Training Loss: 0.643626
# Epoch: 133 	Training Loss: 0.640485
# Epoch: 134 	Training Loss: 0.643902
# Epoch: 135 	Training Loss: 0.642081
# Epoch: 136 	Training Loss: 0.641737
# Epoch: 137 	Training Loss: 0.640216
# Epoch: 138 	Training Loss: 0.640186
# Epoch: 139 	Training Loss: 0.643246
# Epoch: 140 	Training Loss: 0.641112
# Epoch: 141 	Training Loss: 0.645023
# Epoch: 142 	Training Loss: 0.642993
# Epoch: 143 	Training Loss: 0.641318
# Epoch: 144 	Training Loss: 0.640481
# Epoch: 145 	Training Loss: 0.639414
# Epoch: 146 	Training Loss: 0.644560
# Epoch: 147 	Training Loss: 0.640724
# Epoch: 148 	Training Loss: 0.644850
# Epoch: 149 	Training Loss: 0.638167
# Epoch: 150 	Training Loss: 0.635595
# Epoch: 151 	Training Loss: 0.639361
# Epoch: 152 	Training Loss: 0.639510
# Epoch: 153 	Training Loss: 0.637140
# Epoch: 154 	Training Loss: 0.636056
# Epoch: 155 	Training Loss: 0.636735
# Epoch: 156 	Training Loss: 0.640014
# Epoch: 157 	Training Loss: 0.643627
# Epoch: 158 	Training Loss: 0.641266
# Epoch: 159 	Training Loss: 0.634701
# Epoch: 160 	Training Loss: 0.638976
# Epoch: 161 	Training Loss: 0.640325
# Epoch: 162 	Training Loss: 0.634552
# Epoch: 163 	Training Loss: 0.641707
# Epoch: 164 	Training Loss: 0.636090
# Epoch: 165 	Training Loss: 0.635763
# Epoch: 166 	Training Loss: 0.637069
# Epoch: 167 	Training Loss: 0.634217
# Epoch: 168 	Training Loss: 0.634302
# Epoch: 169 	Training Loss: 0.636644
# Epoch: 170 	Training Loss: 0.635888
# Epoch: 171 	Training Loss: 0.639602
# Epoch: 172 	Training Loss: 0.635481
# Epoch: 173 	Training Loss: 0.635230
# Epoch: 174 	Training Loss: 0.640780
# Epoch: 175 	Training Loss: 0.637797
# Epoch: 176 	Training Loss: 0.634321
# Epoch: 177 	Training Loss: 0.634128
# Epoch: 178 	Training Loss: 0.636436
# Epoch: 179 	Training Loss: 0.632426
# Epoch: 180 	Training Loss: 0.630943
# Epoch: 181 	Training Loss: 0.633071
# Epoch: 182 	Training Loss: 0.632746
# Epoch: 183 	Training Loss: 0.638499
# Epoch: 184 	Training Loss: 0.635016
# Epoch: 185 	Training Loss: 0.634441
# Epoch: 186 	Training Loss: 0.635120
# Epoch: 187 	Training Loss: 0.684953
# Epoch: 188 	Training Loss: 0.626235
# Epoch: 189 	Training Loss: 0.625183
# Epoch: 190 	Training Loss: 0.638624
# Epoch: 191 	Training Loss: 0.631527
# Epoch: 192 	Training Loss: 0.626766
# Epoch: 193 	Training Loss: 0.630630
# Epoch: 194 	Training Loss: 0.621686
# Epoch: 195 	Training Loss: 0.618434
# Epoch: 196 	Training Loss: 0.618911
# Epoch: 197 	Training Loss: 0.614645
# Epoch: 198 	Training Loss: 0.614339
# Epoch: 199 	Training Loss: 0.617084
# Epoch: 200 	Training Loss: 0.616046
# Epoch: 201 	Training Loss: 0.613756
# Epoch: 202 	Training Loss: 0.613405
# Epoch: 203 	Training Loss: 0.616863
# Epoch: 204 	Training Loss: 0.618452
# Epoch: 205 	Training Loss: 0.612327
# Epoch: 206 	Training Loss: 0.616484
# Epoch: 207 	Training Loss: 0.621690
# Epoch: 208 	Training Loss: 0.615346
# Epoch: 209 	Training Loss: 0.614780
# Epoch: 210 	Training Loss: 0.616307
# Epoch: 211 	Training Loss: 0.612958
# Epoch: 212 	Training Loss: 0.611561
# Epoch: 213 	Training Loss: 0.619079
# Epoch: 214 	Training Loss: 0.611921
# Epoch: 215 	Training Loss: 0.614795
# Epoch: 216 	Training Loss: 0.612601
# Epoch: 217 	Training Loss: 0.609148
# Epoch: 218 	Training Loss: 0.612270
# Epoch: 219 	Training Loss: 0.606178
# Epoch: 220 	Training Loss: 0.609136
# Epoch: 221 	Training Loss: 0.613068
# Epoch: 222 	Training Loss: 0.613527
# Epoch: 223 	Training Loss: 0.615229
# Epoch: 224 	Training Loss: 0.611631
# Epoch: 225 	Training Loss: 0.614700
# Epoch: 226 	Training Loss: 0.611040
# Epoch: 227 	Training Loss: 0.612029
# Epoch: 228 	Training Loss: 0.615896
# Epoch: 229 	Training Loss: 0.612604
# Epoch: 230 	Training Loss: 0.610877
# Epoch: 231 	Training Loss: 0.611579
# Epoch: 232 	Training Loss: 0.610214
# Epoch: 233 	Training Loss: 0.608282
# Epoch: 234 	Training Loss: 0.610601
# Epoch: 235 	Training Loss: 0.608739
# Epoch: 236 	Training Loss: 0.619443
# Epoch: 237 	Training Loss: 0.615388
# Epoch: 238 	Training Loss: 0.611311
# Epoch: 239 	Training Loss: 0.609360
# Epoch: 240 	Training Loss: 0.618919
# Epoch: 241 	Training Loss: 0.609088
# Epoch: 242 	Training Loss: 0.610279
# Epoch: 243 	Training Loss: 0.611111
# Epoch: 244 	Training Loss: 0.609144
# Epoch: 245 	Training Loss: 0.605429
# Epoch: 246 	Training Loss: 0.609756
# Epoch: 247 	Training Loss: 0.610394
# Epoch: 248 	Training Loss: 0.612259
# Epoch: 249 	Training Loss: 0.608329
# Epoch: 250 	Training Loss: 0.613302
# Epoch: 251 	Training Loss: 0.608048
# Epoch: 252 	Training Loss: 0.604303
# Epoch: 253 	Training Loss: 0.607132
# Epoch: 254 	Training Loss: 0.611528
# Epoch: 255 	Training Loss: 0.616331
# Epoch: 256 	Training Loss: 0.606080
# Epoch: 257 	Training Loss: 0.611548
# Epoch: 258 	Training Loss: 0.607983
# Epoch: 259 	Training Loss: 0.604226
# Epoch: 260 	Training Loss: 0.609637
# Epoch: 261 	Training Loss: 0.606922
# Epoch: 262 	Training Loss: 0.608031
# Epoch: 263 	Training Loss: 0.616669
# Epoch: 264 	Training Loss: 0.606335
# Epoch: 265 	Training Loss: 0.600583
# Epoch: 266 	Training Loss: 0.607425
# Epoch: 267 	Training Loss: 0.599907
# Epoch: 268 	Training Loss: 0.603218
# Epoch: 269 	Training Loss: 0.605668
# Epoch: 270 	Training Loss: 0.605280
# Epoch: 271 	Training Loss: 0.599502
# Epoch: 272 	Training Loss: 0.603700
# Epoch: 273 	Training Loss: 0.597447
# Epoch: 274 	Training Loss: 0.601658
# Epoch: 275 	Training Loss: 0.601462
# Epoch: 276 	Training Loss: 0.601862
# Epoch: 277 	Training Loss: 0.603051
# Epoch: 278 	Training Loss: 0.595624
# Epoch: 279 	Training Loss: 0.594816
# Epoch: 280 	Training Loss: 0.596297
# Epoch: 281 	Training Loss: 0.596713
# Epoch: 282 	Training Loss: 0.603320
# Epoch: 283 	Training Loss: 0.601227
# Epoch: 284 	Training Loss: 0.606508
# Epoch: 285 	Training Loss: 0.598445
# Epoch: 286 	Training Loss: 0.597829
# Epoch: 287 	Training Loss: 0.601361
# Epoch: 288 	Training Loss: 0.596590
# Epoch: 289 	Training Loss: 0.594320
# Epoch: 290 	Training Loss: 0.597387
# Epoch: 291 	Training Loss: 0.599137
# Epoch: 292 	Training Loss: 0.595035
# Epoch: 293 	Training Loss: 0.597492
# Epoch: 294 	Training Loss: 0.610638
# Epoch: 295 	Training Loss: 0.602968
# Epoch: 296 	Training Loss: 0.594097
# Epoch: 297 	Training Loss: 0.594937
# Epoch: 298 	Training Loss: 0.595533
# Epoch: 299 	Training Loss: 0.598681
# Epoch: 300 	Training Loss: 0.605705
# Epoch: 301 	Training Loss: 0.596078
# Epoch: 302 	Training Loss: 0.596220
# Epoch: 303 	Training Loss: 0.606827
# Epoch: 304 	Training Loss: 0.595823
# Epoch: 305 	Training Loss: 0.596776
# Epoch: 306 	Training Loss: 0.600794
# Epoch: 307 	Training Loss: 0.593052
# Epoch: 308 	Training Loss: 0.595367
# Epoch: 309 	Training Loss: 0.592191
# Epoch: 310 	Training Loss: 0.595569
# Epoch: 311 	Training Loss: 0.589815
# Epoch: 312 	Training Loss: 0.593722
# Epoch: 313 	Training Loss: 0.594160
# Epoch: 314 	Training Loss: 0.590600
# Epoch: 315 	Training Loss: 0.594674
# Epoch: 316 	Training Loss: 0.595964
# Epoch: 317 	Training Loss: 0.595764
# Epoch: 318 	Training Loss: 0.595924
# Epoch: 319 	Training Loss: 0.603376
# Epoch: 320 	Training Loss: 0.596255
# Epoch: 321 	Training Loss: 0.593648
# Epoch: 322 	Training Loss: 0.585703
# Epoch: 323 	Training Loss: 0.588343
# Epoch: 324 	Training Loss: 0.589695
# Epoch: 325 	Training Loss: 0.589490
# Epoch: 326 	Training Loss: 0.593514
# Epoch: 327 	Training Loss: 0.592203
# Epoch: 328 	Training Loss: 0.587561
# Epoch: 329 	Training Loss: 0.590684
# Epoch: 330 	Training Loss: 0.591993
# Epoch: 331 	Training Loss: 0.591452
# Epoch: 332 	Training Loss: 0.594480
# Epoch: 333 	Training Loss: 0.592033
# Epoch: 334 	Training Loss: 0.590353
# Epoch: 335 	Training Loss: 0.591217
# Epoch: 336 	Training Loss: 0.587240
# Epoch: 337 	Training Loss: 0.585231
# Epoch: 338 	Training Loss: 0.586922
# Epoch: 339 	Training Loss: 0.584911
# Epoch: 340 	Training Loss: 0.587377
# Epoch: 341 	Training Loss: 0.586796
# Epoch: 342 	Training Loss: 0.592803
# Epoch: 343 	Training Loss: 0.590797
# Epoch: 344 	Training Loss: 0.587407
# Epoch: 345 	Training Loss: 0.586592
# Epoch: 346 	Training Loss: 0.583941
# Epoch: 347 	Training Loss: 0.584857
# Epoch: 348 	Training Loss: 0.586949
# Epoch: 349 	Training Loss: 0.586066
# Epoch: 350 	Training Loss: 0.586508
# Epoch: 351 	Training Loss: 0.591231
# Epoch: 352 	Training Loss: 0.585301
# Epoch: 353 	Training Loss: 0.594016
# Epoch: 354 	Training Loss: 0.592764
# Epoch: 355 	Training Loss: 0.585962
# Epoch: 356 	Training Loss: 0.583882
# Epoch: 357 	Training Loss: 0.581933
# Epoch: 358 	Training Loss: 0.584814
# Epoch: 359 	Training Loss: 0.587040
# Epoch: 360 	Training Loss: 0.591465
# Epoch: 361 	Training Loss: 0.582036
# Epoch: 362 	Training Loss: 0.582657
# Epoch: 363 	Training Loss: 0.587834
# Epoch: 364 	Training Loss: 0.587140
# Epoch: 365 	Training Loss: 0.585325
# Epoch: 366 	Training Loss: 0.591605
# Epoch: 367 	Training Loss: 0.584041
# Epoch: 368 	Training Loss: 0.590948
# Epoch: 369 	Training Loss: 0.583000
# Epoch: 370 	Training Loss: 0.579894
# Epoch: 371 	Training Loss: 0.581530
# Epoch: 372 	Training Loss: 0.589385
# Epoch: 373 	Training Loss: 0.582223
# Epoch: 374 	Training Loss: 0.584669
# Epoch: 375 	Training Loss: 0.588802
# Epoch: 376 	Training Loss: 0.583062
# Epoch: 377 	Training Loss: 0.581114
# Epoch: 378 	Training Loss: 0.584876
# Epoch: 379 	Training Loss: 0.585477
# Epoch: 380 	Training Loss: 0.583749
# Epoch: 381 	Training Loss: 0.580573
# Epoch: 382 	Training Loss: 0.589888
# Epoch: 383 	Training Loss: 0.579839
# Epoch: 384 	Training Loss: 0.579462
# Epoch: 385 	Training Loss: 0.583117
# Epoch: 386 	Training Loss: 0.587026
# Epoch: 387 	Training Loss: 0.581877
# Epoch: 388 	Training Loss: 0.587455
# Epoch: 389 	Training Loss: 0.584552
# Epoch: 390 	Training Loss: 0.582683
# Epoch: 391 	Training Loss: 0.582433
# Epoch: 392 	Training Loss: 0.578543
# Epoch: 393 	Training Loss: 0.575464
# Epoch: 394 	Training Loss: 0.583833
# Epoch: 395 	Training Loss: 0.581146
# Epoch: 396 	Training Loss: 0.584138
# Epoch: 397 	Training Loss: 0.583429
# Epoch: 398 	Training Loss: 0.586387
# Epoch: 399 	Training Loss: 0.588747
# Epoch: 400 	Training Loss: 0.578601
# Epoch: 401 	Training Loss: 0.582188
# Epoch: 402 	Training Loss: 0.583320
# Epoch: 403 	Training Loss: 0.578628
# Epoch: 404 	Training Loss: 0.578201
# Epoch: 405 	Training Loss: 0.580831
# Epoch: 406 	Training Loss: 0.580129
# Epoch: 407 	Training Loss: 0.587755
# Epoch: 408 	Training Loss: 0.592868
# Epoch: 409 	Training Loss: 0.576850
# Epoch: 410 	Training Loss: 0.584685
# Epoch: 411 	Training Loss: 0.584119
# Epoch: 412 	Training Loss: 0.585178
# Epoch: 413 	Training Loss: 0.587557
# Epoch: 414 	Training Loss: 0.583270
# Epoch: 415 	Training Loss: 0.577793
# Epoch: 416 	Training Loss: 0.575441
# Epoch: 417 	Training Loss: 0.576913
# Epoch: 418 	Training Loss: 0.574666
# Epoch: 419 	Training Loss: 0.576615
# Epoch: 420 	Training Loss: 0.580424
# Epoch: 421 	Training Loss: 0.575934
# Epoch: 422 	Training Loss: 0.573222
# Epoch: 423 	Training Loss: 0.574965
# Epoch: 424 	Training Loss: 0.576783
# Epoch: 425 	Training Loss: 0.583420
# Epoch: 426 	Training Loss: 0.593133
# Epoch: 427 	Training Loss: 0.595150
# Epoch: 428 	Training Loss: 0.580296
# Epoch: 429 	Training Loss: 0.579091
# Epoch: 430 	Training Loss: 0.582206
# Epoch: 431 	Training Loss: 0.579957
# Epoch: 432 	Training Loss: 0.576000
# Epoch: 433 	Training Loss: 0.575034
# Epoch: 434 	Training Loss: 0.585106
# Epoch: 435 	Training Loss: 0.578317
# Epoch: 436 	Training Loss: 0.580304
# Epoch: 437 	Training Loss: 0.579739
# Epoch: 438 	Training Loss: 0.583320
# Epoch: 439 	Training Loss: 0.576559
# Epoch: 440 	Training Loss: 0.577780
# Epoch: 441 	Training Loss: 0.575668
# Epoch: 442 	Training Loss: 0.571602
# Epoch: 443 	Training Loss: 0.570331
# Epoch: 444 	Training Loss: 0.577049
# Epoch: 445 	Training Loss: 0.589575
# Epoch: 446 	Training Loss: 0.585432
# Epoch: 447 	Training Loss: 0.583891
# Epoch: 448 	Training Loss: 0.579958
# Epoch: 449 	Training Loss: 0.582894
# Epoch: 450 	Training Loss: 0.571737
# Epoch: 451 	Training Loss: 0.573302
# Epoch: 452 	Training Loss: 0.575611
# Epoch: 453 	Training Loss: 0.574356
# Epoch: 454 	Training Loss: 0.575920
# Epoch: 455 	Training Loss: 0.581132
# Epoch: 456 	Training Loss: 0.579251
# Epoch: 457 	Training Loss: 0.579873
# Epoch: 458 	Training Loss: 0.576439
# Epoch: 459 	Training Loss: 0.568723
# Epoch: 460 	Training Loss: 0.573214
# Epoch: 461 	Training Loss: 0.571859
# Epoch: 462 	Training Loss: 0.571631
# Epoch: 463 	Training Loss: 0.572148
# Epoch: 464 	Training Loss: 0.570912
# Epoch: 465 	Training Loss: 0.578532
# Epoch: 466 	Training Loss: 0.576957
# Epoch: 467 	Training Loss: 0.575566
# Epoch: 468 	Training Loss: 0.571596
# Epoch: 469 	Training Loss: 0.566287
# Epoch: 470 	Training Loss: 0.576017
# Epoch: 471 	Training Loss: 0.576132
# Epoch: 472 	Training Loss: 0.571741
# Epoch: 473 	Training Loss: 0.574458
# Epoch: 474 	Training Loss: 0.571616
# Epoch: 475 	Training Loss: 0.571822
# Epoch: 476 	Training Loss: 0.572819
# Epoch: 477 	Training Loss: 0.576744
# Epoch: 478 	Training Loss: 0.584335
# Epoch: 479 	Training Loss: 0.575322
# Epoch: 480 	Training Loss: 0.574707
# Epoch: 481 	Training Loss: 0.572751
# Epoch: 482 	Training Loss: 0.571550
# Epoch: 483 	Training Loss: 0.570136
# Epoch: 484 	Training Loss: 0.574409
# Epoch: 485 	Training Loss: 0.566633
# Epoch: 486 	Training Loss: 0.574549
# Epoch: 487 	Training Loss: 0.566981
# Epoch: 488 	Training Loss: 0.573530
# Epoch: 489 	Training Loss: 0.582152
# Epoch: 490 	Training Loss: 0.579093
# Epoch: 491 	Training Loss: 0.578667
# Epoch: 492 	Training Loss: 0.572029
# Epoch: 493 	Training Loss: 0.573826
# Epoch: 494 	Training Loss: 0.573184
# Epoch: 495 	Training Loss: 0.571521
# Epoch: 496 	Training Loss: 0.565432
# Epoch: 497 	Training Loss: 0.568959
# Epoch: 498 	Training Loss: 0.564287
# Epoch: 499 	Training Loss: 0.568897
# Train Loss:	 0.5689 , 	Test Loss:	 0.71706
# Train Accuracy:	 0.69432 , 	Test Accuracy:	 0.66765
# Precision:	 0.79711 , 	Recall:	 0.50039

# %%
results = train_net(train_loader,dev_loader,lr_rate)
# Out:
# Epoch: 0 	Training Loss: 0.610951
# Epoch: 1 	Training Loss: 0.622308
# Epoch: 2 	Training Loss: 0.613131
# Epoch: 3 	Training Loss: 0.608873
# Epoch: 4 	Training Loss: 0.611121
# Epoch: 5 	Training Loss: 0.611727
# Epoch: 6 	Training Loss: 0.618484
# Epoch: 7 	Training Loss: 0.616167
# Epoch: 8 	Training Loss: 0.612821
# Epoch: 9 	Training Loss: 0.608014
# Epoch: 10 	Training Loss: 0.613490
# Epoch: 11 	Training Loss: 0.614206
# Epoch: 12 	Training Loss: 0.615566
# Epoch: 13 	Training Loss: 0.610815
# Epoch: 14 	Training Loss: 0.607292
# Epoch: 15 	Training Loss: 0.610810
# Epoch: 16 	Training Loss: 0.609949
# Epoch: 17 	Training Loss: 0.612860
# Epoch: 18 	Training Loss: 0.612217
# Epoch: 19 	Training Loss: 0.615462
# Epoch: 20 	Training Loss: 0.613304
# Epoch: 21 	Training Loss: 0.615534
# Epoch: 22 	Training Loss: 0.612467
# Epoch: 23 	Training Loss: 0.617161
# Epoch: 24 	Training Loss: 0.612236
# Epoch: 25 	Training Loss: 0.612942
# Epoch: 26 	Training Loss: 0.614413
# Epoch: 27 	Training Loss: 0.607981
# Epoch: 28 	Training Loss: 0.612907
# Epoch: 29 	Training Loss: 0.611457
# Epoch: 30 	Training Loss: 0.608201
# Epoch: 31 	Training Loss: 0.608295
# Epoch: 32 	Training Loss: 0.608478
# Epoch: 33 	Training Loss: 0.610069
# Epoch: 34 	Training Loss: 0.609101
# Epoch: 35 	Training Loss: 0.611812
# Epoch: 36 	Training Loss: 0.607873
# Epoch: 37 	Training Loss: 0.610366
# Epoch: 38 	Training Loss: 0.613091
# Epoch: 39 	Training Loss: 0.614490
# Epoch: 40 	Training Loss: 0.610532
# Epoch: 41 	Training Loss: 0.611890
# Epoch: 42 	Training Loss: 0.615034
# Epoch: 43 	Training Loss: 0.614262
# Epoch: 44 	Training Loss: 0.610223
# Epoch: 45 	Training Loss: 0.608925
# Epoch: 46 	Training Loss: 0.611174
# Epoch: 47 	Training Loss: 0.613945
# Epoch: 48 	Training Loss: 0.609200
# Epoch: 49 	Training Loss: 0.610396
# Epoch: 50 	Training Loss: 0.611791
# Epoch: 51 	Training Loss: 0.611816
# Epoch: 52 	Training Loss: 0.611574
# Epoch: 53 	Training Loss: 0.609653
# Epoch: 54 	Training Loss: 0.611245
# Epoch: 55 	Training Loss: 0.607614
# Epoch: 56 	Training Loss: 0.613000
# Epoch: 57 	Training Loss: 0.608479
# Epoch: 58 	Training Loss: 0.604540
# Epoch: 59 	Training Loss: 0.608947
# Epoch: 60 	Training Loss: 0.608552
# Epoch: 61 	Training Loss: 0.606046
# Epoch: 62 	Training Loss: 0.606874
# Epoch: 63 	Training Loss: 0.614036
# Epoch: 64 	Training Loss: 0.611371
# Epoch: 65 	Training Loss: 0.609247
# Epoch: 66 	Training Loss: 0.607814
# Epoch: 67 	Training Loss: 0.607581
# Epoch: 68 	Training Loss: 0.613333
# Epoch: 69 	Training Loss: 0.612273
# Epoch: 70 	Training Loss: 0.606711
# Epoch: 71 	Training Loss: 0.614479
# Epoch: 72 	Training Loss: 0.612343
# Epoch: 73 	Training Loss: 0.607477
# Epoch: 74 	Training Loss: 0.610711
# Epoch: 75 	Training Loss: 0.607311
# Epoch: 76 	Training Loss: 0.609452
# Epoch: 77 	Training Loss: 0.608538
# Epoch: 78 	Training Loss: 0.607404
# Epoch: 79 	Training Loss: 0.607542
# Epoch: 80 	Training Loss: 0.610426
# Epoch: 81 	Training Loss: 0.610577
# Epoch: 82 	Training Loss: 0.616215
# Epoch: 83 	Training Loss: 0.605963
# Epoch: 84 	Training Loss: 0.613013
# Epoch: 85 	Training Loss: 0.610474
# Epoch: 86 	Training Loss: 0.615288
# Epoch: 87 	Training Loss: 0.610504
# Epoch: 88 	Training Loss: 0.607662
# Epoch: 89 	Training Loss: 0.607789
# Epoch: 90 	Training Loss: 0.605789
# Epoch: 91 	Training Loss: 0.610326
# Epoch: 92 	Training Loss: 0.607924
# Epoch: 93 	Training Loss: 0.603960
# Epoch: 94 	Training Loss: 0.605855
# Epoch: 95 	Training Loss: 0.606933
# Epoch: 96 	Training Loss: 0.609441
# Epoch: 97 	Training Loss: 0.603571
# Epoch: 98 	Training Loss: 0.611741
# Epoch: 99 	Training Loss: 0.606176
# Epoch: 100 	Training Loss: 0.608308
# Epoch: 101 	Training Loss: 0.609400
# Epoch: 102 	Training Loss: 0.607218
# Epoch: 103 	Training Loss: 0.605744
# Epoch: 104 	Training Loss: 0.608728
# Epoch: 105 	Training Loss: 0.606169
# Epoch: 106 	Training Loss: 0.606522
# Epoch: 107 	Training Loss: 0.605781
# Epoch: 108 	Training Loss: 0.610928
# Epoch: 109 	Training Loss: 0.609311
# Epoch: 110 	Training Loss: 0.607425
# Epoch: 111 	Training Loss: 0.607733
# Epoch: 112 	Training Loss: 0.606662
# Epoch: 113 	Training Loss: 0.606467
# Epoch: 114 	Training Loss: 0.608321
# Epoch: 115 	Training Loss: 0.606895
# Epoch: 116 	Training Loss: 0.608595
# Epoch: 117 	Training Loss: 0.612833
# Epoch: 118 	Training Loss: 0.611201
# Epoch: 119 	Training Loss: 0.606118
# Epoch: 120 	Training Loss: 0.602792
# Epoch: 121 	Training Loss: 0.610025
# Epoch: 122 	Training Loss: 0.603046
# Epoch: 123 	Training Loss: 0.607203
# Epoch: 124 	Training Loss: 0.606431
# Epoch: 125 	Training Loss: 0.606610
# Epoch: 126 	Training Loss: 0.606111
# Epoch: 127 	Training Loss: 0.602730
# Epoch: 128 	Training Loss: 0.604534
# Epoch: 129 	Training Loss: 0.608307
# Epoch: 130 	Training Loss: 0.608662
# Epoch: 131 	Training Loss: 0.609294
# Epoch: 132 	Training Loss: 0.604936
# Epoch: 133 	Training Loss: 0.607715
# Epoch: 134 	Training Loss: 0.605278
# Epoch: 135 	Training Loss: 0.610491
# Epoch: 136 	Training Loss: 0.602988
# Epoch: 137 	Training Loss: 0.602262
# Epoch: 138 	Training Loss: 0.607756
# Epoch: 139 	Training Loss: 0.606992
# Epoch: 140 	Training Loss: 0.604743
# Epoch: 141 	Training Loss: 0.612824
# Epoch: 142 	Training Loss: 0.604690
# Epoch: 143 	Training Loss: 0.605423
# Epoch: 144 	Training Loss: 0.611826
# Epoch: 145 	Training Loss: 0.609674
# Epoch: 146 	Training Loss: 0.605623
# Epoch: 147 	Training Loss: 0.603589
# Epoch: 148 	Training Loss: 0.605860
# Epoch: 149 	Training Loss: 0.604875
# Epoch: 150 	Training Loss: 0.609159
# Epoch: 151 	Training Loss: 0.607337
# Epoch: 152 	Training Loss: 0.601675
# Epoch: 153 	Training Loss: 0.602445
# Epoch: 154 	Training Loss: 0.603579
# Epoch: 155 	Training Loss: 0.608574
# Epoch: 156 	Training Loss: 0.603312
# Epoch: 157 	Training Loss: 0.606096
# Epoch: 158 	Training Loss: 0.603508
# Epoch: 159 	Training Loss: 0.603333
# Epoch: 160 	Training Loss: 0.606922
# Epoch: 161 	Training Loss: 0.607131
# Epoch: 162 	Training Loss: 0.601777
# Epoch: 163 	Training Loss: 0.605122
# Epoch: 164 	Training Loss: 0.606213
# Epoch: 165 	Training Loss: 0.606604
# Epoch: 166 	Training Loss: 0.612106
# Epoch: 167 	Training Loss: 0.605901
# Epoch: 168 	Training Loss: 0.605756
# Epoch: 169 	Training Loss: 0.605540
# Epoch: 170 	Training Loss: 0.619568
# Epoch: 171 	Training Loss: 0.612169
# Epoch: 172 	Training Loss: 0.609886
# Epoch: 173 	Training Loss: 0.605192
# Epoch: 174 	Training Loss: 0.603282
# Epoch: 175 	Training Loss: 0.606493
# Epoch: 176 	Training Loss: 0.602222
# Epoch: 177 	Training Loss: 0.603493
# Epoch: 178 	Training Loss: 0.604793
# Epoch: 179 	Training Loss: 0.608517
# Epoch: 180 	Training Loss: 0.616583
# Epoch: 181 	Training Loss: 0.602837
# Epoch: 182 	Training Loss: 0.605578
# Epoch: 183 	Training Loss: 0.603682
# Epoch: 184 	Training Loss: 0.603043
# Epoch: 185 	Training Loss: 0.602209
# Epoch: 186 	Training Loss: 0.604428
# Epoch: 187 	Training Loss: 0.602497
# Epoch: 188 	Training Loss: 0.601334
# Epoch: 189 	Training Loss: 0.605020
# Epoch: 190 	Training Loss: 0.606061
# Epoch: 191 	Training Loss: 0.606861
# Epoch: 192 	Training Loss: 0.603911
# Epoch: 193 	Training Loss: 0.607048
# Epoch: 194 	Training Loss: 0.602446
# Epoch: 195 	Training Loss: 0.601380
# Epoch: 196 	Training Loss: 0.606928
# Epoch: 197 	Training Loss: 0.608192
# Epoch: 198 	Training Loss: 0.602580
# Epoch: 199 	Training Loss: 0.609300
# Epoch: 200 	Training Loss: 0.604579
# Epoch: 201 	Training Loss: 0.604647
# Epoch: 202 	Training Loss: 0.601748
# Epoch: 203 	Training Loss: 0.602341
# Epoch: 204 	Training Loss: 0.606297
# Epoch: 205 	Training Loss: 0.603219
# Epoch: 206 	Training Loss: 0.602929
# Epoch: 207 	Training Loss: 0.606124
# Epoch: 208 	Training Loss: 0.603335
# Epoch: 209 	Training Loss: 0.604878
# Epoch: 210 	Training Loss: 0.599370
# Epoch: 211 	Training Loss: 0.600287
# Epoch: 212 	Training Loss: 0.599046
# Epoch: 213 	Training Loss: 0.601240
# Epoch: 214 	Training Loss: 0.607665
# Epoch: 215 	Training Loss: 0.602605
# Epoch: 216 	Training Loss: 0.604917
# Epoch: 217 	Training Loss: 0.606136
# Epoch: 218 	Training Loss: 0.607087
# Epoch: 219 	Training Loss: 0.602894
# Epoch: 220 	Training Loss: 0.603704
# Epoch: 221 	Training Loss: 0.608594
# Epoch: 222 	Training Loss: 0.605565
# Epoch: 223 	Training Loss: 0.601566
# Epoch: 224 	Training Loss: 0.600206
# Epoch: 225 	Training Loss: 0.603192
# Epoch: 226 	Training Loss: 0.602859
# Epoch: 227 	Training Loss: 0.603330
# Epoch: 228 	Training Loss: 0.607495
# Epoch: 229 	Training Loss: 0.602199
# Epoch: 230 	Training Loss: 0.605109
# Epoch: 231 	Training Loss: 0.603650
# Epoch: 232 	Training Loss: 0.601869
# Epoch: 233 	Training Loss: 0.603715
# Epoch: 234 	Training Loss: 0.602347
# Epoch: 235 	Training Loss: 0.604395
# Epoch: 236 	Training Loss: 0.603729
# Epoch: 237 	Training Loss: 0.602330
# Epoch: 238 	Training Loss: 0.601370
# Epoch: 239 	Training Loss: 0.600691
# Epoch: 240 	Training Loss: 0.611197
# Epoch: 241 	Training Loss: 0.602315
# Epoch: 242 	Training Loss: 0.602260
# Epoch: 243 	Training Loss: 0.605105
# Epoch: 244 	Training Loss: 0.603154
# Epoch: 245 	Training Loss: 0.615380
# Epoch: 246 	Training Loss: 0.602158
# Epoch: 247 	Training Loss: 0.602731
# Epoch: 248 	Training Loss: 0.613833
# Epoch: 249 	Training Loss: 0.605774
# Epoch: 250 	Training Loss: 0.605217
# Epoch: 251 	Training Loss: 0.603112
# Epoch: 252 	Training Loss: 0.600125
# Epoch: 253 	Training Loss: 0.606584
# Epoch: 254 	Training Loss: 0.606110
# Epoch: 255 	Training Loss: 0.601179
# Epoch: 256 	Training Loss: 0.599500
# Epoch: 257 	Training Loss: 0.600210
# Epoch: 258 	Training Loss: 0.603458
# Epoch: 259 	Training Loss: 0.600396
# Epoch: 260 	Training Loss: 0.598357
# Epoch: 261 	Training Loss: 0.601002
# Epoch: 262 	Training Loss: 0.603831
# Epoch: 263 	Training Loss: 0.599850
# Epoch: 264 	Training Loss: 0.609167
# Epoch: 265 	Training Loss: 0.597615
# Epoch: 266 	Training Loss: 0.603834
# Epoch: 267 	Training Loss: 0.606699
# Epoch: 268 	Training Loss: 0.603169
# Epoch: 269 	Training Loss: 0.602696
# Epoch: 270 	Training Loss: 0.602261
# Epoch: 271 	Training Loss: 0.603683
# Epoch: 272 	Training Loss: 0.602782
# Epoch: 273 	Training Loss: 0.601177
# Epoch: 274 	Training Loss: 0.601545
# Epoch: 275 	Training Loss: 0.598886
# Epoch: 276 	Training Loss: 0.598402
# Epoch: 277 	Training Loss: 0.606428
# Epoch: 278 	Training Loss: 0.600332
# Epoch: 279 	Training Loss: 0.600955
# Epoch: 280 	Training Loss: 0.598844
# Epoch: 281 	Training Loss: 0.605188
# Epoch: 282 	Training Loss: 0.603273
# Epoch: 283 	Training Loss: 0.603397
# Epoch: 284 	Training Loss: 0.603573
# Epoch: 285 	Training Loss: 0.601460
# Epoch: 286 	Training Loss: 0.603049
# Epoch: 287 	Training Loss: 0.596907
# Epoch: 288 	Training Loss: 0.604705
# Epoch: 289 	Training Loss: 0.602423
# Epoch: 290 	Training Loss: 0.600173
# Epoch: 291 	Training Loss: 0.601632
# Epoch: 292 	Training Loss: 0.601158
# Epoch: 293 	Training Loss: 0.600441
# Epoch: 294 	Training Loss: 0.600926
# Epoch: 295 	Training Loss: 0.599732
# Epoch: 296 	Training Loss: 0.606661
# Epoch: 297 	Training Loss: 0.600392
# Epoch: 298 	Training Loss: 0.599636
# Epoch: 299 	Training Loss: 0.606394
# Epoch: 300 	Training Loss: 0.599552
# Epoch: 301 	Training Loss: 0.597813
# Epoch: 302 	Training Loss: 0.594820
# Epoch: 303 	Training Loss: 0.601081
# Epoch: 304 	Training Loss: 0.599120
# Epoch: 305 	Training Loss: 0.602532
# Epoch: 306 	Training Loss: 0.604904
# Epoch: 307 	Training Loss: 0.601373
# Epoch: 308 	Training Loss: 0.600157
# Epoch: 309 	Training Loss: 0.602523
# Epoch: 310 	Training Loss: 0.597090
# Epoch: 311 	Training Loss: 0.602273
# Epoch: 312 	Training Loss: 0.601188
# Epoch: 313 	Training Loss: 0.600654
# Epoch: 314 	Training Loss: 0.599923
# Epoch: 315 	Training Loss: 0.612275
# Epoch: 316 	Training Loss: 0.599741
# Epoch: 317 	Training Loss: 0.602743
# Epoch: 318 	Training Loss: 0.604546
# Epoch: 319 	Training Loss: 0.596770
# Epoch: 320 	Training Loss: 0.599442
# Epoch: 321 	Training Loss: 0.597122
# Epoch: 322 	Training Loss: 0.596436
# Epoch: 323 	Training Loss: 0.601349
# Epoch: 324 	Training Loss: 0.601210
# Epoch: 325 	Training Loss: 0.600584
# Epoch: 326 	Training Loss: 0.600336
# Epoch: 327 	Training Loss: 0.596654
# Epoch: 328 	Training Loss: 0.600495
# Epoch: 329 	Training Loss: 0.600585
# Epoch: 330 	Training Loss: 0.597850
# Epoch: 331 	Training Loss: 0.602952
# Epoch: 332 	Training Loss: 0.612287
# Epoch: 333 	Training Loss: 0.598820
# Epoch: 334 	Training Loss: 0.602399
# Epoch: 335 	Training Loss: 0.598829
# Epoch: 336 	Training Loss: 0.603565
# Epoch: 337 	Training Loss: 0.600169
# Epoch: 338 	Training Loss: 0.598201
# Epoch: 339 	Training Loss: 0.597967
# Epoch: 340 	Training Loss: 0.606948
# Epoch: 341 	Training Loss: 0.596784
# Epoch: 342 	Training Loss: 0.597498
# Epoch: 343 	Training Loss: 0.599125
# Epoch: 344 	Training Loss: 0.599384
# Epoch: 345 	Training Loss: 0.601028
# Epoch: 346 	Training Loss: 0.594556
# Epoch: 347 	Training Loss: 0.598152
# Epoch: 348 	Training Loss: 0.598268
# Epoch: 349 	Training Loss: 0.602049
# Epoch: 350 	Training Loss: 0.607983
# Epoch: 351 	Training Loss: 0.609593
# Epoch: 352 	Training Loss: 0.602280
# Epoch: 353 	Training Loss: 0.598402
# Epoch: 354 	Training Loss: 0.598713
# Epoch: 355 	Training Loss: 0.599331
# Epoch: 356 	Training Loss: 0.606587
# Epoch: 357 	Training Loss: 0.599716
# Epoch: 358 	Training Loss: 0.606863
# Epoch: 359 	Training Loss: 0.608544
# Epoch: 360 	Training Loss: 0.600684
# Epoch: 361 	Training Loss: 0.596080
# Epoch: 362 	Training Loss: 0.598119
# Epoch: 363 	Training Loss: 0.598666
# Epoch: 364 	Training Loss: 0.599585
# Epoch: 365 	Training Loss: 0.599906
# Epoch: 366 	Training Loss: 0.600717
# Epoch: 367 	Training Loss: 0.601824
# Epoch: 368 	Training Loss: 0.597232
# Epoch: 369 	Training Loss: 0.600501
# Epoch: 370 	Training Loss: 0.599688
# Epoch: 371 	Training Loss: 0.607384
# Epoch: 372 	Training Loss: 0.604405
# Epoch: 373 	Training Loss: 0.596376
# Epoch: 374 	Training Loss: 0.599220
# Epoch: 375 	Training Loss: 0.597088
# Epoch: 376 	Training Loss: 0.597245
# Epoch: 377 	Training Loss: 0.599409
# Epoch: 378 	Training Loss: 0.598217
# Epoch: 379 	Training Loss: 0.598725
# Epoch: 380 	Training Loss: 0.597746
# Epoch: 381 	Training Loss: 0.605096
# Epoch: 382 	Training Loss: 0.596731
# Epoch: 383 	Training Loss: 0.599038
# Epoch: 384 	Training Loss: 0.595482
# Epoch: 385 	Training Loss: 0.597748
# Epoch: 386 	Training Loss: 0.596993
# Epoch: 387 	Training Loss: 0.595752
# Epoch: 388 	Training Loss: 0.595249
# Epoch: 389 	Training Loss: 0.598908
# Epoch: 390 	Training Loss: 0.597434
# Epoch: 391 	Training Loss: 0.594876
# Epoch: 392 	Training Loss: 0.599894
# Epoch: 393 	Training Loss: 0.599039
# Epoch: 394 	Training Loss: 0.599668
# Epoch: 395 	Training Loss: 0.595843
# Epoch: 396 	Training Loss: 0.600351
# Epoch: 397 	Training Loss: 0.602344
# Epoch: 398 	Training Loss: 0.598435
# Epoch: 399 	Training Loss: 0.596959
# Epoch: 400 	Training Loss: 0.596695
# Epoch: 401 	Training Loss: 0.597865
# Epoch: 402 	Training Loss: 0.597079
# Epoch: 403 	Training Loss: 0.600698
# Epoch: 404 	Training Loss: 0.597243
# Epoch: 405 	Training Loss: 0.597136
# Epoch: 406 	Training Loss: 0.593612
# Epoch: 407 	Training Loss: 0.595487
# Epoch: 408 	Training Loss: 0.595910
# Epoch: 409 	Training Loss: 0.595940
# Epoch: 410 	Training Loss: 0.596549
# Epoch: 411 	Training Loss: 0.594930
# Epoch: 412 	Training Loss: 0.601642
# Epoch: 413 	Training Loss: 0.600192
# Epoch: 414 	Training Loss: 0.605999
# Epoch: 415 	Training Loss: 0.597839
# Epoch: 416 	Training Loss: 0.596492
# Epoch: 417 	Training Loss: 0.599156
# Epoch: 418 	Training Loss: 0.595380
# Epoch: 419 	Training Loss: 0.595776
# Epoch: 420 	Training Loss: 0.594441
# Epoch: 421 	Training Loss: 0.598540
# Epoch: 422 	Training Loss: 0.594597
# Epoch: 423 	Training Loss: 0.596937
# Epoch: 424 	Training Loss: 0.594341
# Epoch: 425 	Training Loss: 0.594977
# Epoch: 426 	Training Loss: 0.595425
# Epoch: 427 	Training Loss: 0.593471
# Epoch: 428 	Training Loss: 0.599783
# Epoch: 429 	Training Loss: 0.594880
# Epoch: 430 	Training Loss: 0.593941
# Epoch: 431 	Training Loss: 0.596390
# Epoch: 432 	Training Loss: 0.601014
# Epoch: 433 	Training Loss: 0.601729
# Epoch: 434 	Training Loss: 0.602273
# Epoch: 435 	Training Loss: 0.592484
# Epoch: 436 	Training Loss: 0.595718
# Epoch: 437 	Training Loss: 0.594721
# Epoch: 438 	Training Loss: 0.600047
# Epoch: 439 	Training Loss: 0.594176
# Epoch: 440 	Training Loss: 0.593256
# Epoch: 441 	Training Loss: 0.596828
# Epoch: 442 	Training Loss: 0.596338
# Epoch: 443 	Training Loss: 0.593862
# Epoch: 444 	Training Loss: 0.595638
# Epoch: 445 	Training Loss: 0.598780
# Epoch: 446 	Training Loss: 0.596476
# Epoch: 447 	Training Loss: 0.597301
# Epoch: 448 	Training Loss: 0.600510
# Epoch: 449 	Training Loss: 0.594079
# Epoch: 450 	Training Loss: 0.600274
# Epoch: 451 	Training Loss: 0.600969
# Epoch: 452 	Training Loss: 0.596689
# Epoch: 453 	Training Loss: 0.594739
# Epoch: 454 	Training Loss: 0.592629
# Epoch: 455 	Training Loss: 0.597483
# Epoch: 456 	Training Loss: 0.599622
# Epoch: 457 	Training Loss: 0.592041
# Epoch: 458 	Training Loss: 0.593658
# Epoch: 459 	Training Loss: 0.595882
# Epoch: 460 	Training Loss: 0.601018
# Epoch: 461 	Training Loss: 0.603275
# Epoch: 462 	Training Loss: 0.592425
# Epoch: 463 	Training Loss: 0.592787
# Epoch: 464 	Training Loss: 0.595305
# Epoch: 465 	Training Loss: 0.592670
# Epoch: 466 	Training Loss: 0.594787
# Epoch: 467 	Training Loss: 0.597776
# Epoch: 468 	Training Loss: 0.596358
# Epoch: 469 	Training Loss: 0.598142
# Epoch: 470 	Training Loss: 0.594908
# Epoch: 471 	Training Loss: 0.595979
# Epoch: 472 	Training Loss: 0.594373
# Epoch: 473 	Training Loss: 0.594634
# Epoch: 474 	Training Loss: 0.594532
# Epoch: 475 	Training Loss: 0.595080
# Epoch: 476 	Training Loss: 0.592043
# Epoch: 477 	Training Loss: 0.596340
# Epoch: 478 	Training Loss: 0.593021
# Epoch: 479 	Training Loss: 0.595287
# Epoch: 480 	Training Loss: 0.595106
# Epoch: 481 	Training Loss: 0.593099
# Epoch: 482 	Training Loss: 0.601510
# Epoch: 483 	Training Loss: 0.596759
# Epoch: 484 	Training Loss: 0.599752
# Epoch: 485 	Training Loss: 0.596751
# Epoch: 486 	Training Loss: 0.594297
# Epoch: 487 	Training Loss: 0.596259
# Epoch: 488 	Training Loss: 0.595952
# Epoch: 489 	Training Loss: 0.596236
# Epoch: 490 	Training Loss: 0.596944
# Epoch: 491 	Training Loss: 0.593951
# Epoch: 492 	Training Loss: 0.595495
# Epoch: 493 	Training Loss: 0.597581
# Epoch: 494 	Training Loss: 0.595097
# Epoch: 495 	Training Loss: 0.598768
# Epoch: 496 	Training Loss: 0.597529
# Epoch: 497 	Training Loss: 0.597770
# Epoch: 498 	Training Loss: 0.593360
# Epoch: 499 	Training Loss: 0.593517
# Train Loss:	 0.59352 , 	Test Loss:	 0.64682
# Train Accuracy:	 0.68138 , 	Test Accuracy:	 0.66982
# Precision:	 0.75385 , 	Recall:	 0.5553

# %%
420
Train Loss:	 0.62915 , 	Test Loss:	 0.66995
Train Accuracy:	 0.65166 , 	Test Accuracy:	 0.6357
Precision:	 0.67342 , 	Recall:	 0.59462

# %%
last_model = model

# %%
## save model
outfile = open("model_1024.pkl",'wb')
pickle.dump(last_model, outfile)
outfile.close()

# %%
## model_1 is the best model
loadfile = open("model_1.pkl",'rb')
saved_model = pickle.load(loadfile)
loadfile.close()
test_net(dev_loader, saved_model, torch.nn.BCELoss())
# Out:
# (0.013583977685072031, 0.9649573037790697, 0.9985232543254862, 1.0)

# %%
loadfile = open("model_init.pkl",'rb')
model_init = pickle.load(loadfile)
loadfile.close()

# %%
import copy
from sklearn.model_selection import KFold
kfold = KFold(n_splits=10)
batch_size = 64
cv_results = {}

for fold, (train_index, test_index) in enumerate(kfold.split(x, y)):
    x_train_fold = x[train_index]
    x_test_fold = x[test_index]
    y_train_fold = y[train_index]
    y_test_fold = y[test_index]
    
    train_loader = torch.utils.data.DataLoader(dataset=tuple(zip(x_train_fold,y_train_fold)), batch_size = batch_size, shuffle = True)
    test_loader = torch.utils.data.DataLoader(dataset=tuple(zip(x_test_fold,y_test_fold)), batch_size = batch_size, shuffle = False)
    
    model.load_state_dict(init_state)
    optimizer.load_state_dict(init_state_opt)
    model.to(device)
    
    cv_results[fold] = train_net(train_loader,dev_loader,lr_rate)
# Out:
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/huangraelene/opt/anaconda3/envs/tnsfl/lib/python3.7/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([3])) that is different to the input size (torch.Size([3, 1])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# 100%|██████████| 10/10 [00:53<00:00,  5.37s/it]
# Train Loss:  0.013925376385699998 , Test Loss:  0.013601134293694578
# Train Accuracy:  0.9612101765422078 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
# 100%|██████████| 10/10 [00:55<00:00,  5.58s/it]
# Train Loss:  0.013784325032620066 , Test Loss:  0.014498367940299187
# Train Accuracy:  0.961520900974026 , Test Accuracy:  0.9627997819767442
# Precision:  0.9992732558139535 , Recall:  1.0
# 100%|██████████| 10/10 [01:02<00:00,  6.28s/it]
# Train Loss:  0.013643661441529027 , Test Loss:  0.013601053983546517
# Train Accuracy:  0.9619457690746753 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
# 100%|██████████| 10/10 [00:56<00:00,  5.66s/it]
# Train Loss:  0.014065557252627793 , Test Loss:  0.014249967757855886
# Train Accuracy:  0.9609628652597403 , Test Accuracy:  0.962425054505814
# Precision:  0.9996249062265566 , Recall:  1.0
# 100%|██████████| 10/10 [00:55<00:00,  5.51s/it]
# Train Loss:  0.013222004240870553 , Test Loss:  0.014368281549503849
# Train Accuracy:  0.9634359780844156 , Test Accuracy:  0.9624477652616279
# Precision:  0.9996366279069767 , Recall:  1.0
# 100%|██████████| 10/10 [01:01<00:00,  6.19s/it]
# Train Loss:  0.01420654689110242 , Test Loss:  0.013601260678878818
# Train Accuracy:  0.9604999492694806 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
# 100%|██████████| 10/10 [00:58<00:00,  5.83s/it]
# Train Loss:  0.014347694744022834 , Test Loss:  0.01360138194422887
# Train Accuracy:  0.9599736201298701 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
# 100%|██████████| 10/10 [00:58<00:00,  5.83s/it]
# Train Loss:  0.013362392565465094 , Test Loss:  0.013601053896962392
# Train Accuracy:  0.9627194094967533 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
#   0%|          | 0/10 [00:00<?, ?it/s]/Users/huangraelene/opt/anaconda3/envs/tnsfl/lib/python3.7/site-packages/torch/nn/modules/loss.py:498: UserWarning: Using a target size (torch.Size([4])) that is different to the input size (torch.Size([4, 1])) is deprecated. Please ensure they have the same size.
#   return F.binary_cross_entropy(input, target, weight=self.weight, reduction=self.reduction)
# 100%|██████████| 10/10 [00:57<00:00,  5.75s/it]
# Train Loss:  0.01378476469192368 , Test Loss:  0.014431673950200908
# Train Accuracy:  0.961711140422078 , Test Accuracy:  0.962425054505814
# Precision:  0.9996249062265566 , Recall:  1.0
# 100%|██████████| 10/10 [00:51<00:00,  5.16s/it]
# Train Loss:  0.013643774487471012 , Test Loss:  0.01360114166206253
# Train Accuracy:  0.9619711343344156 , Test Accuracy:  0.9620957485465116
# Precision:  1.0 , Recall:  1.0
